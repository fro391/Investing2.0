# %%
import datetime
import time
import requests

import json
import os
import pandas as pd
import numpy as np

#threading
import threading
import timeit

from email.mime.text import MIMEText
import smtplib

import gc
import sys

import traceback

#declare global lock object
global lock
lock = threading.Lock()

# %%
def symbol_downloader_intraday (symbol, directory, days=30, days_ago=0):
    dt = datetime.datetime.now()
    UnixTime = int(time.mktime(dt.timetuple()))
    #web variables
    url = 'https://query1.finance.yahoo.com/v8/finance/chart/'+symbol+'?period1='+str(UnixTime-86400*(days+days_ago))+'&period2='+str(UnixTime-86400*days_ago)+'&interval=5m&indicators=quote%7Csma~60&includePrePost=true&events=div%7Csplit%7Cearn&lang=en-CA&region=CA&corsDomain=ca.finance.yahoo.com'
    #proxies
    http_proxy  = ''
    https_proxy = ''
    ftp_proxy   = ''
    proxyDict = { 
                  "http"  : http_proxy, 
                  "https" : https_proxy, 
                  "ftp"   : ftp_proxy
                }

    hdr = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.101 Safari/537.36',
       'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
       'Connection': 'keep-alive'}
    
    try:
        resp = requests.get(url, headers=hdr)
        if resp.status_code != 200:
            # This means something went wrong.
            print(resp.status_code)
        data = json.loads(resp.text)
        #json unpack
        timestamp = data['chart']['result'][0]['timestamp']
        timestamp = [datetime.datetime.fromtimestamp(x).strftime('%Y%m%d-%H%M') for x in timestamp]
        quote = data['chart']['result'][0]['indicators']['quote'][0]
        stock_df = pd.DataFrame(quote)
        #index is symbol and timestamp
        stock_df.index = [str(x) for x in timestamp]

        #moving averages
        stock_df['vol20'] = stock_df['volume'].rolling(window=20).mean()
        stock_df['sma5'] = stock_df['close'].rolling(window=5).mean()
        stock_df['sma8'] = stock_df['close'].rolling(window=8).mean()
        stock_df['sma13'] = stock_df['close'].rolling(window=13).mean()
        stock_df = stock_df.dropna()

        #stock_df.drop(['close', 'high', 'low', 'open','volume','sma','vol20'], axis=1, inplace=True)
        stock_df = stock_df.dropna()
        stock_df = stock_df[~(stock_df == np.inf).any(axis=1)]
        if len(stock_df) != 0:
            stock_df.to_csv('{}{}.csv'.format(directory,symbol[:4]))
        try:
            lock.acquire()
            #clear memory
            gc.collect()
        finally:
            lock.release()
        
    except Exception:
        print(symbol)
        print(traceback.format_exc())
        # or
        print(sys.exc_info()[2])

# %%
#Delete files in Directory
directory = './data5m/'
filelist = [ f for f in os.listdir(directory) if f.endswith(".csv") ]
for f in filelist:
    os.remove(os.path.join(directory, f))

# %%
if __name__ == '__main__':

    #start timer
    start = timeit.default_timer()

    symbolslist = open('symbolsIntraD.txt').read().split('\n')

    directory = './data5m/'

    threadlist = []

    for u in symbolslist:

        t = threading.Thread(target = symbol_downloader_intraday,args=(u,directory))
        t.start()
        threadlist.append(t)
        #sets top limit of active threads to 20
        while threading.activeCount()>20:
            a=0
        #print threading.activeCount()

    for b in threadlist:
        b.join()
    print ("# of threads: ", len(threadlist))
# Out:
# 404
# CCHW
# Traceback (most recent call last):
#   File "<ipython-input-2-5f15393b6c16>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x0000011FFB282F08>
# 404
# CURL
# Traceback (most recent call last):
#   File "<ipython-input-2-5f15393b6c16>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x0000011FFB80D788>
# 404
# GTBI
# Traceback (most recent call last):
#   File "<ipython-input-2-5f15393b6c16>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x0000011FFB75A888>
# 404
# GUY.
# Traceback (most recent call last):
#   File "<ipython-input-2-5f15393b6c16>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# GUYF
# 404
# GUY.
# Traceback (most recent call last):
#   File "<ipython-input-2-5f15393b6c16>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Traceback (most recent call last):
#   File "<ipython-input-2-5f15393b6c16>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x0000011FF6DC7588>
#
# <traceback object at 0x0000011FFB7D8C08>
# <traceback object at 0x0000011FFBAA3B08>
# 404
# KOR.
# Traceback (most recent call last):
#   File "<ipython-input-2-5f15393b6c16>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x0000011FFB753BC8>
# 404
# RNX.
# Traceback (most recent call last):
#   File "<ipython-input-2-5f15393b6c16>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x0000011FFB56E108>
# 404
# TCW.
# Traceback (most recent call last):
#   File "<ipython-input-2-5f15393b6c16>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x0000011FFB501E88>
# 404
# WILD
# Traceback (most recent call last):
#   File "<ipython-input-2-5f15393b6c16>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x0000011FFB436688>
# 404
#
# Traceback (most recent call last):
#   File "<ipython-input-2-5f15393b6c16>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# IndexError: list index out of range
#
# <traceback object at 0x0000011FFB6EFA88>
# # of threads:  118

# %%
#IntraDay Buy-In signal @5m candle sticks
gc.collect()
to_send = ''
directory = './data5m/'
# get list with filenames in folder and throw away all non ncsv
files = [f for f in os.listdir(directory) if f.endswith('.csv')]
for f in files:
    try:
        ticker_df = pd.read_csv(os.path.join(directory, f))
        jones_df = pd.read_csv(os.path.join(directory,'^DJI.csv'))
        
        stock_df = pd.merge(ticker_df, jones_df, left_index=True, right_index=True)
        
        for i in range(int((len(stock_df)*0.3))): #engulfing candel pattern looping through all available data 
            
            window = 59 #number of days back from today to look at for slope
            
            i += 1 #start range from 1 instead of 0
            
            open0 =  float(stock_df['open_x'].iloc[-i])
            close0 =  float(stock_df['close_x'].iloc[-i])
            open_1 = float(stock_df['open_x'].iloc[-(i+1)])
            close_1 = float(stock_df['close_x'].iloc[-(i+1)])
            
            sma5 = float(stock_df['sma5_x'].iloc[-i])
            sma8 = float(stock_df['sma8_x'].iloc[-i])
            sma13 = float(stock_df['sma13_x'].iloc[-i])
            
            mktVlcty0 = float(stock_df['volume_x'].iloc[-i])*float(stock_df['close_x'].iloc[-i])
            
            volume0 = (float(stock_df['volume_x'].iloc[-i])+0.001)/(float(stock_df['vol20_x'].iloc[-i])+0.001)
            
            j_open0 =  float(stock_df['open_y'].iloc[-i])
            j_close0 =  float(stock_df['close_y'].iloc[-i])
            stockPChange = (close0-open0)/open0 
            jonesPChange = (j_close0-j_open0)/j_open0
            
            timeOfDay = stock_df['Unnamed: 0_x'].iloc[-i][-4:]
            date0 = stock_df['Unnamed: 0_x'].iloc[-i][:8]
            tday_date = str(datetime.datetime.today().strftime('%Y%m%d'))

            #core logic
            if  stockPChange > abs(jonesPChange)*10\
                and sma5<close0 \
                and sma5> open0 \
                and sma5 > sma8 and sma8 > sma13 \
                and close0 <= 20 and close0 >= 0.5 \
                and mktVlcty0 > 100000\
                and volume0 >= 2\
                and timeOfDay != '0930'\
                and date0 == tday_date:

                to_send += '{} has 5m buy-in signal with high volume on {}, and is under $20. Close price: {} \n'.format(f[:-4],(stock_df['Unnamed: 0_x'].iloc[-i]),close0)
                print ('{} has 5m buy-in signal with high volume on {}, and is under $20. Close price: {} \n'.format(f[:-4],(stock_df['Unnamed: 0_x'].iloc[-i]),close0))

    except IndexError:
        print("{} has too few rows".format(f))
        pass
    except Exception:
        print(traceback.format_exc())
        # or
        print(sys.exc_info()[2])
# Out:
# ABEO has 5m buy-in signal with high volume on 20200527-1410, and is under $20. Close price: 3.259999990463257
#
# AFMD has 5m buy-in signal with high volume on 20200529-1550, and is under $20. Close price: 3.2999999523162837
#
# AFMD has 5m buy-in signal with high volume on 20200528-0950, and is under $20. Close price: 3.2850000858306885
#
# AFMD has 5m buy-in signal with high volume on 20200527-1415, and is under $20. Close price: 3.220000028610229
#
# AXU has 5m buy-in signal with high volume on 20200529-1040, and is under $20. Close price: 2.309999942779541
#
# CBAY has 5m buy-in signal with high volume on 20200522-1555, and is under $20. Close price: 3.859999895095825
#
# CBAY has 5m buy-in signal with high volume on 20200520-1555, and is under $20. Close price: 4.059999942779541
#
# CBAY has 5m buy-in signal with high volume on 20200520-0950, and is under $20. Close price: 4.050000190734863
#
# CBAY has 5m buy-in signal with high volume on 20200519-1525, and is under $20. Close price: 3.984999895095825
#
# CFMS has 5m buy-in signal with high volume on 20200528-1035, and is under $20. Close price: 1.1399999856948853
#
# CIDM has 5m buy-in signal with high volume on 20200528-1310, and is under $20. Close price: 0.8999999761581421
#
# CLSN has 5m buy-in signal with high volume on 20200529-1545, and is under $20. Close price: 3.0199999809265137
#
# CLSN has 5m buy-in signal with high volume on 20200528-1045, and is under $20. Close price: 3.0999999046325684
#
# DCAR has 5m buy-in signal with high volume on 20200521-1305, and is under $20. Close price: 1.1699999570846558
#
# DFIN has 5m buy-in signal with high volume on 20200527-1555, and is under $20. Close price: 8.640000343322754
#
# FLDM has 5m buy-in signal with high volume on 20200521-1150, and is under $20. Close price: 4.690100193023682
#
# FLDM has 5m buy-in signal with high volume on 20200520-1330, and is under $20. Close price: 4.40500020980835
#
# GNUS has 5m buy-in signal with high volume on 20200515-1325, and is under $20. Close price: 1.6799999475479126
#
# GNUS has 5m buy-in signal with high volume on 20200515-1310, and is under $20. Close price: 1.6599999666213991
#
# GPRO has 5m buy-in signal with high volume on 20200519-1305, and is under $20. Close price: 4.25
#
# GPRO has 5m buy-in signal with high volume on 20200519-1220, and is under $20. Close price: 4.2083001136779785
#
# GPRO has 5m buy-in signal with high volume on 20200519-1155, and is under $20. Close price: 4.10230016708374
#
# IZEA has 5m buy-in signal with high volume on 20200515-1000, and is under $20. Close price: 0.6141999959945679
#
# IZEA has 5m buy-in signal with high volume on 20200514-1220, and is under $20. Close price: 0.6924999952316284
#
# IZEA has 5m buy-in signal with high volume on 20200514-0940, and is under $20. Close price: 0.7501999735832214
#
# IZEA has 5m buy-in signal with high volume on 20200513-1530, and is under $20. Close price: 0.6349999904632568
#
# IZEA has 5m buy-in signal with high volume on 20200513-1100, and is under $20. Close price: 0.5799000263214111
#
# KOPN has 5m buy-in signal with high volume on 20200520-1540, and is under $20. Close price: 0.9700000286102296
#
# KOPN has 5m buy-in signal with high volume on 20200520-1500, and is under $20. Close price: 0.9469910264015198
#
# LEDS has 5m buy-in signal with high volume on 20200526-1555, and is under $20. Close price: 3.1401000022888184
#
# LL has 5m buy-in signal with high volume on 20200528-0955, and is under $20. Close price: 10.854999542236328
#
# LL has 5m buy-in signal with high volume on 20200528-0940, and is under $20. Close price: 10.4399995803833
#
# LL has 5m buy-in signal with high volume on 20200527-1330, and is under $20. Close price: 9.600199699401855
#
# LL has 5m buy-in signal with high volume on 20200522-1110, and is under $20. Close price: 7.96999979019165
#
# MGI has 5m buy-in signal with high volume on 20200529-0935, and is under $20. Close price: 2.3299999237060547
#
# MGI has 5m buy-in signal with high volume on 20200528-0940, and is under $20. Close price: 2.3310999870300293
#
# MGI has 5m buy-in signal with high volume on 20200527-1025, and is under $20. Close price: 2.259999990463257
#
# MGI has 5m buy-in signal with high volume on 20200526-1500, and is under $20. Close price: 2.1600000858306885
#
# NEPT has 5m buy-in signal with high volume on 20200522-1135, and is under $20. Close price: 3.1800000667572017
#
# NEPT has 5m buy-in signal with high volume on 20200522-0935, and is under $20. Close price: 2.990000009536743
#
# NNDM has 5m buy-in signal with high volume on 20200522-1040, and is under $20. Close price: 3.059999942779541
#
# NNDM has 5m buy-in signal with high volume on 20200521-1405, and is under $20. Close price: 3.134999990463257
#
# OBSV has 5m buy-in signal with high volume on 20200521-1355, and is under $20. Close price: 4.449900150299072
#
# OBSV has 5m buy-in signal with high volume on 20200521-1315, and is under $20. Close price: 4.336400032043457
#
# PEIX has 5m buy-in signal with high volume on 20200529-1350, and is under $20. Close price: 0.625
#
# PHUN has 5m buy-in signal with high volume on 20200522-1530, and is under $20. Close price: 1.3600000143051147
#
# RENN has 5m buy-in signal with high volume on 20200527-0935, and is under $20. Close price: 4.989999771118164
#
# RIOT has 5m buy-in signal with high volume on 20200519-1045, and is under $20. Close price: 2.250099897384644
#
# SNCA has 5m buy-in signal with high volume on 20200528-1005, and is under $20. Close price: 0.9199000000953674
#
# TORC has 5m buy-in signal with high volume on 20200529-1550, and is under $20. Close price: 2.2100000381469727
#
# TORC has 5m buy-in signal with high volume on 20200528-1045, and is under $20. Close price: 2.438499927520752
#
# TORC has 5m buy-in signal with high volume on 20200526-1110, and is under $20. Close price: 2.240000009536743
#
# TRVN has 5m buy-in signal with high volume on 20200527-0940, and is under $20. Close price: 1.5099999904632568
#
# TTPH has 5m buy-in signal with high volume on 20200522-1040, and is under $20. Close price: 3.1087000370025635
#
# TTPH has 5m buy-in signal with high volume on 20200522-0940, and is under $20. Close price: 2.9200000762939453
#
# UBX has 5m buy-in signal with high volume on 20200528-1510, and is under $20. Close price: 8.090000152587889
#
# UPWK has 5m buy-in signal with high volume on 20200519-1340, and is under $20. Close price: 12.859999656677244
#
# UPWK has 5m buy-in signal with high volume on 20200519-1000, and is under $20. Close price: 12.75
#
# VFF has 5m buy-in signal with high volume on 20200529-1550, and is under $20. Close price: 5.440000057220459
#
# VFF has 5m buy-in signal with high volume on 20200529-1540, and is under $20. Close price: 5.480000019073486
#
# VFF has 5m buy-in signal with high volume on 20200529-0945, and is under $20. Close price: 5.507800102233887
#
# VFF has 5m buy-in signal with high volume on 20200526-1435, and is under $20. Close price: 6.070000171661378
#
# VUZI has 5m buy-in signal with high volume on 20200522-1400, and is under $20. Close price: 2.990000009536743
#
# VUZI has 5m buy-in signal with high volume on 20200522-1040, and is under $20. Close price: 2.9500000476837163
#
# ZSAN has 5m buy-in signal with high volume on 20200527-1455, and is under $20. Close price: 1.0449999570846558
#
# ZYNE has 5m buy-in signal with high volume on 20200522-1500, and is under $20. Close price: 6.25

# %%
#email output
with open('C:\\Users\\Richard\\Desktop\\Python\\hotmail.txt', 'rb') as f:
    email_list = str(f.read()).split(',')
    emailAddress = email_list[0][2:]
    password = email_list[1][:-1]

    msg = MIMEText(to_send)
    recipients = [emailAddress, 'michelleusdenski@gmail.com','guowei88888@msn.com']#'jacob.si@outlook.com','Greggh_101@hotmail.com']
    msg['Subject'] = '%s stock analysis - Intraday Buy-ins: potentials - %s' % (str(datetime.datetime.today().strftime('%Y%m%d-%H%M')), str(len(to_send.split('\n'))-1))
    msg['From'] = emailAddress
    msg['To'] = ', '.join(recipients)
    try:
        s = smtplib.SMTP('smtp-mail.outlook.com', 25)
        s.ehlo()  # Hostname to send for this command defaults to the fully qualified domain name of the local host.
        s.starttls()  # Puts connection to SMTP server in TLS mode
        s.ehlo()
        s.login(emailAddress, password)
        s.sendmail(emailAddress, recipients, msg.as_string())
        s.quit()
        print ('email sent to: %s' % emailAddress)
    except:
        raise

# %%
'''
Backlog: 
-Incorporate obv and macd indicators
-auto drop from list when daily price drops below 5 day moving average
-scrape float and add to logic
'''
