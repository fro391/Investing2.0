# %%
import datetime
import time
import requests

import json
import os
import pandas as pd
import numpy as np

#threading
import threading
import timeit

from email.mime.text import MIMEText
import smtplib

import gc
import sys

import traceback

#declare global lock object
global lock
lock = threading.Lock()

# %%
def symbol_downloader_intraday (symbol, directory, days=30, days_ago=0):
    dt = datetime.datetime.now()
    UnixTime = int(time.mktime(dt.timetuple()))
    #web variables
    url = 'https://query1.finance.yahoo.com/v8/finance/chart/'+symbol+'?period1='+str(UnixTime-86400*(days+days_ago))+'&period2='+str(UnixTime-86400*days_ago)+'&interval=5m&indicators=quote%7Csma~60&includePrePost=true&events=div%7Csplit%7Cearn&lang=en-CA&region=CA&corsDomain=ca.finance.yahoo.com'
    #proxies
    http_proxy  = ''
    https_proxy = ''
    ftp_proxy   = ''
    proxyDict = { 
                  "http"  : http_proxy, 
                  "https" : https_proxy, 
                  "ftp"   : ftp_proxy
                }

    hdr = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.101 Safari/537.36',
       'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
       'Connection': 'keep-alive'}
    
    try:
        resp = requests.get(url, headers=hdr)
        if resp.status_code != 200:
            # This means something went wrong.
            print(resp.status_code)
        data = json.loads(resp.text)
        #json unpack
        timestamp = data['chart']['result'][0]['timestamp']
        timestamp = [datetime.datetime.fromtimestamp(x).strftime('%Y%m%d-%H%M') for x in timestamp]
        quote = data['chart']['result'][0]['indicators']['quote'][0]
        stock_df = pd.DataFrame(quote)
        #index is symbol and timestamp
        stock_df.index = [str(x) for x in timestamp]

        #moving averages
        stock_df['vol20'] = stock_df['volume'].rolling(window=20).mean()
        stock_df['sma5'] = stock_df['close'].rolling(window=5).mean()
        stock_df['sma8'] = stock_df['close'].rolling(window=8).mean()
        stock_df['sma13'] = stock_df['close'].rolling(window=13).mean()
        stock_df['sma21'] = stock_df['close'].rolling(window=21).mean()
        stock_df = stock_df.dropna()

        #stock_df.drop(['close', 'high', 'low', 'open','volume','sma','vol20'], axis=1, inplace=True)
        stock_df = stock_df.dropna()
        stock_df = stock_df[~(stock_df == np.inf).any(axis=1)]
        if len(stock_df) != 0:
            stock_df.to_csv('{}{}.csv'.format(directory,symbol[:4]))
        try:
            lock.acquire()
            #clear memory
            gc.collect()
        finally:
            lock.release()
        
    except Exception:
        print(symbol)
        print(traceback.format_exc())
        # or
        print(sys.exc_info()[2])

# %%
#Delete files in Directory
directory = './data5m/'
filelist = [ f for f in os.listdir(directory) if f.endswith(".csv") ]
for f in filelist:
    os.remove(os.path.join(directory, f))

# %%
if __name__ == '__main__':

    #start timer
    start = timeit.default_timer()

    symbolslist = open('symbolsIntraD.txt').read().split('\n')

    directory = './data5m/'

    threadlist = []

    for u in symbolslist:

        t = threading.Thread(target = symbol_downloader_intraday,args=(u,directory))
        t.start()
        threadlist.append(t)
        #sets top limit of active threads to 20
        while threading.activeCount()>20:
            a=0
        #print threading.activeCount()

    for b in threadlist:
        b.join()
    print ("# of threads: ", len(threadlist))
# Out:
# 404
# ERIX
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E872764FC8>
# 404
#
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# IndexError: list index out of range
#
# <traceback object at 0x000001E873F6B688>
# 404
# CRH.
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E87401D808>
# 404
# TGOD
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873E91308>
# 404
# JPAS
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873986448>
# 404
# CRRF
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873B22448>
# 404
# BB.T
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873CC97C8>
# 404
# GUY.
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873D5FE48>
# 404
# GTBI
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873B938C8>
# 404
# TSRY
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E874050688>
# 404
# EXN.
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873FC1108>
# 404
# RNX.
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E872750348>
# 404
# BRLA
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E872756888>
# 404
# CURL
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873EBE048>
# 404
# EDR.
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873B8D048>
# 404
# CIA.
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873F32388>
# 404
# CJR-
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873E06E88>
# INNT
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# <traceback object at 0x000001E873C66748>
# 404
# GUYF
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873CBFB48>
# LABS
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# <traceback object at 0x000001E873B0A788>
# 404
# PD.T
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873A29248>
# SAUC
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# <traceback object at 0x000001E8739AF288>
# 404
# BOIV
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873B68A88>
# 404
# PLNH
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873A777C8>
# 404
# KOR.
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873C3AE08>
# 404
# TMD.
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873F3BE48>
# 404
# SKVK
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E8739CA508>
# 404
# CCHW
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873AE8248>
# 404
# BACH
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873977988>
# 404
# PEI-
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873A79148>
# CRZO
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# <traceback object at 0x000001E873BA28C8>
# 404
# IVN.
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# <traceback object at 0x000001E873D22688>
# 404
#
# Traceback (most recent call last):
#   File "<ipython-input-5-5182891d8c1c>", line 27, in symbol_downloader_intraday
#     timestamp = data['chart']['result'][0]['timestamp']
# IndexError: list index out of range
#
# <traceback object at 0x000001E873FBBDC8>
# # of threads:  226

# %%
#IntraDay Buy-In signal @5m candle sticks
gc.collect()
to_send = ''
directory = './data5m/'
# get list with filenames in folder and throw away all non ncsv
files = [f for f in os.listdir(directory) if f.endswith('.csv')]
for f in files:
    try:
        ticker_df = pd.read_csv(os.path.join(directory, f))
        jones_df = pd.read_csv(os.path.join(directory,'^DJI.csv'))
        
        stock_df = pd.merge(ticker_df, jones_df, left_index=True, right_index=True)
        
        for i in range(int((len(stock_df)*0.3))): #engulfing candel pattern looping through all available data 
            
            window = 59 #number of days back from today to look at for slope
            
            i += 1 #start range from 1 instead of 0
            
            open0 =  float(stock_df['open_x'].iloc[-i])
            close0 =  float(stock_df['close_x'].iloc[-i])
            open_1 = float(stock_df['open_x'].iloc[-(i+1)])
            close_1 = float(stock_df['close_x'].iloc[-(i+1)])
            
            #Moving averages
            sma5 = float(stock_df['sma5_x'].iloc[-i])
            sma8 = float(stock_df['sma8_x'].iloc[-i])
            sma13 = float(stock_df['sma13_x'].iloc[-i])
            sma21 = float(stock_df['sma21_x'].iloc[-i])
            
            sma5_1 = float(stock_df['sma5_x'].iloc[-(i+1)])
            sma8_1 = float(stock_df['sma8_x'].iloc[-(i+1)])
            sma13_1 = float(stock_df['sma13_x'].iloc[-(i+1)])
            sma21_1 = float(stock_df['sma21_x'].iloc[-(i+1)])
            
            sma5_2 = float(stock_df['sma5_x'].iloc[-(i+2)])
            sma8_2 = float(stock_df['sma8_x'].iloc[-(i+2)])
            sma13_2 = float(stock_df['sma13_x'].iloc[-(i+2)])
            sma21_2 = float(stock_df['sma21_x'].iloc[-(i+2)])  
            
            #moving average momentum indicators
            s5 =  ((sma5-sma5_1)/sma5)*1000
            s8 =  ((sma8-sma8_1)/sma8)*1000
            s13 =  ((sma13-sma13_1)/sma13)*1000
            s21 =  ((sma21-sma21_1)/sma21)*1000
            
            z5 =  ((sma5_1-sma5_2)/sma5_1)*1000
            z8 =  ((sma8_1-sma8_2)/sma8_1)*1000
            z13 =  ((sma13_1-sma13_2)/sma13_1)*1000
            z21 =  ((sma21_1-sma21_2)/sma21_1)*1000
            
            #volume indicators
            mktVlcty0 = float(stock_df['volume_x'].iloc[-i])*float(stock_df['close_x'].iloc[-i])
            
            volume0 = (float(stock_df['volume_x'].iloc[-i])+0.001)/(float(stock_df['vol20_x'].iloc[-i])+0.001)
            
            #market indexes
            j_open0 =  float(stock_df['open_y'].iloc[-i])
            j_close0 =  float(stock_df['close_y'].iloc[-i])
            stockPChange = (close0-open0)/open0 
            jonesPChange = (j_close0-j_open0)/j_open0
            
            #time of day
            timeOfDay = stock_df['Unnamed: 0_x'].iloc[-i][-4:]
            date0 = stock_df['Unnamed: 0_x'].iloc[-i][:8]
            tday_date = str(datetime.datetime.today().strftime('%Y%m%d'))

            #core logic
            if  stockPChange > abs(jonesPChange)*10\
                and open0 < close0 \
                and s5 >= z5 and s8 >= z8 and s13 >= z13 and s21 >= z21\
                and close0 <= 5 and close0 >= 0.5 \
                and mktVlcty0 > 100000\
                and volume0 >= 2\
                and timeOfDay != '0930'\
                and date0 == tday_date:

                to_send += '{} has 5m buy-in signal with high volume on {}, and is under $5. Close price: {} \n'.format(f[:-4],(stock_df['Unnamed: 0_x'].iloc[-i]),close0)

    except IndexError:
        print("{} has too few rows".format(f))
        pass
    except Exception:
        print(traceback.format_exc())
        # or
        print(sys.exc_info()[2])

# %%
print (to_send)
# Out:
# ACST has 5m buy-in signal with high volume on 20200604-0950, and is under $10. Close price: 0.8748000264167786
# ACST has 5m buy-in signal with high volume on 20200604-0945, and is under $10. Close price: 0.8398000001907349
# ACTG has 5m buy-in signal with high volume on 20200604-1550, and is under $10. Close price: 3.2000000476837163
# ACTG has 5m buy-in signal with high volume on 20200604-1415, and is under $10. Close price: 3.190000057220459
# BOXL has 5m buy-in signal with high volume on 20200604-1250, and is under $10. Close price: 1.2194000482559204
# BOXL has 5m buy-in signal with high volume on 20200604-1150, and is under $10. Close price: 1.0700000524520874
# BOXL has 5m buy-in signal with high volume on 20200604-0950, and is under $10. Close price: 0.9549499750137328
# CETX has 5m buy-in signal with high volume on 20200604-1425, and is under $10. Close price: 2.315000057220459
# CETX has 5m buy-in signal with high volume on 20200604-1410, and is under $10. Close price: 2.220000028610229
# CETX has 5m buy-in signal with high volume on 20200604-1405, and is under $10. Close price: 2.1199998855590816
# CETX has 5m buy-in signal with high volume on 20200604-1210, and is under $10. Close price: 1.8799999952316284
# CETX has 5m buy-in signal with high volume on 20200604-0950, and is under $10. Close price: 1.899399995803833
# CETX has 5m buy-in signal with high volume on 20200604-0935, and is under $10. Close price: 1.8594000339508057
# CIDM has 5m buy-in signal with high volume on 20200604-1550, and is under $10. Close price: 3.640000104904175
# CIDM has 5m buy-in signal with high volume on 20200604-1505, and is under $10. Close price: 3.6800000667572017
# CIDM has 5m buy-in signal with high volume on 20200604-0935, and is under $10. Close price: 4.559999942779541
# CLSN has 5m buy-in signal with high volume on 20200604-1010, and is under $10. Close price: 2.892400026321411
# CLSN has 5m buy-in signal with high volume on 20200604-0950, and is under $10. Close price: 2.7699999809265137
# CMCM has 5m buy-in signal with high volume on 20200604-1025, and is under $10. Close price: 3.0899999141693115
# CMCM has 5m buy-in signal with high volume on 20200604-1015, and is under $10. Close price: 3.0799999237060547
# DGLY has 5m buy-in signal with high volume on 20200604-1530, and is under $10. Close price: 2.1099998950958248
# DGLY has 5m buy-in signal with high volume on 20200604-1325, and is under $10. Close price: 2.1300001144409184
# DGLY has 5m buy-in signal with high volume on 20200604-1205, and is under $10. Close price: 2.0199999809265137
# DGLY has 5m buy-in signal with high volume on 20200604-1030, and is under $10. Close price: 1.999899983406067
# DGLY has 5m buy-in signal with high volume on 20200604-1025, and is under $10. Close price: 1.7799999713897705
# DPW has 5m buy-in signal with high volume on 20200604-0950, and is under $10. Close price: 1.5999000072479248
# DPW has 5m buy-in signal with high volume on 20200604-0945, and is under $10. Close price: 1.5499999523162842
# DPW has 5m buy-in signal with high volume on 20200604-0940, and is under $10. Close price: 1.4700000286102295
# DTEA has 5m buy-in signal with high volume on 20200604-1325, and is under $10. Close price: 1.440000057220459
# DTEA has 5m buy-in signal with high volume on 20200604-1315, and is under $10. Close price: 1.2999999523162842
# EIGI has 5m buy-in signal with high volume on 20200604-1555, and is under $10. Close price: 3.650000095367432
# EIGI has 5m buy-in signal with high volume on 20200604-1550, and is under $10. Close price: 3.619999885559082
# FOSL has 5m buy-in signal with high volume on 20200604-1315, and is under $10. Close price: 4.565000057220459
# FOSL has 5m buy-in signal with high volume on 20200604-1000, and is under $10. Close price: 4.183800220489502
# FOSL has 5m buy-in signal with high volume on 20200604-0950, and is under $10. Close price: 4.079999923706056
# FOSL has 5m buy-in signal with high volume on 20200604-0940, and is under $10. Close price: 3.9300000667572017
# GNLN has 5m buy-in signal with high volume on 20200604-0950, and is under $10. Close price: 3.6726999282836914
# KIRK has 5m buy-in signal with high volume on 20200604-1340, and is under $10. Close price: 1.25
# OBSV has 5m buy-in signal with high volume on 20200604-0955, and is under $10. Close price: 4.920000076293945
# PEIX has 5m buy-in signal with high volume on 20200604-1005, and is under $10. Close price: 0.8082000017166138
# PEIX has 5m buy-in signal with high volume on 20200604-0935, and is under $10. Close price: 0.8633999824523926
# PUMP has 5m buy-in signal with high volume on 20200604-1000, and is under $10. Close price: 4.864999771118164
# RES has 5m buy-in signal with high volume on 20200604-1550, and is under $10. Close price: 3.6549999713897705
# RNWK has 5m buy-in signal with high volume on 20200604-0935, and is under $10. Close price: 1.7999999523162842
# ROSE has 5m buy-in signal with high volume on 20200604-1035, and is under $10. Close price: 0.5908560156822205
# ROSE has 5m buy-in signal with high volume on 20200604-1030, and is under $10. Close price: 0.5153110027313232
# RRD has 5m buy-in signal with high volume on 20200604-0950, and is under $10. Close price: 1.2620999813079834
# RRD has 5m buy-in signal with high volume on 20200604-0935, and is under $10. Close price: 1.1677999496459959
# SOLO has 5m buy-in signal with high volume on 20200604-0935, and is under $10. Close price: 1.5099999904632568
# SPPI has 5m buy-in signal with high volume on 20200604-1445, and is under $10. Close price: 3.065000057220459
# TAST has 5m buy-in signal with high volume on 20200604-1030, and is under $10. Close price: 4.679999828338623
# TIGR has 5m buy-in signal with high volume on 20200604-0945, and is under $10. Close price: 3.5299999713897705
# TRXC has 5m buy-in signal with high volume on 20200604-1140, and is under $10. Close price: 0.5805000066757202
# TRXC has 5m buy-in signal with high volume on 20200604-1135, and is under $10. Close price: 0.5440000295639038
# UGP has 5m buy-in signal with high volume on 20200604-1555, and is under $10. Close price: 3.670000076293945
# VUZI has 5m buy-in signal with high volume on 20200604-1030, and is under $10. Close price: 2.5699999332427983

# %%
#email output
with open('C:\\Users\\Richard\\Desktop\\Python\\hotmail.txt', 'rb') as f:
    email_list = str(f.read()).split(',')
    emailAddress = email_list[0][2:]
    password = email_list[1][:-1]

    msg = MIMEText(to_send)
    recipients = [emailAddress, 'michelleusdenski@gmail.com','guowei88888@msn.com']#'jacob.si@outlook.com','Greggh_101@hotmail.com']
    msg['Subject'] = '%s stock analysis - Intraday Buy-ins: potentials - %s' % (str(datetime.datetime.today().strftime('%Y%m%d-%H%M')), str(len(to_send.split('\n'))-1))
    msg['From'] = emailAddress
    msg['To'] = ', '.join(recipients)
    try:
        s = smtplib.SMTP('smtp-mail.outlook.com', 25)
        s.ehlo()  # Hostname to send for this command defaults to the fully qualified domain name of the local host.
        s.starttls()  # Puts connection to SMTP server in TLS mode
        s.ehlo()
        s.login(emailAddress, password)
        s.sendmail(emailAddress, recipients, msg.as_string())
        s.quit()
        print ('email sent to: %s' % emailAddress)
    except:
        raise

# %%
'''
Backlog: 
-Incorporate obv and macd indicators
-scrape float and add to logic
'''
