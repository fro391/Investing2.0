# %%
import datetime
import time
import requests

import json
import os
import pandas as pd
import numpy as np

#threading
import threading
import timeit

from email.mime.text import MIMEText
import smtplib

import gc
import sys

import traceback

#declare global lock object
global lock
lock = threading.Lock()

# %%
def symbol_downloader_intraday (symbol, directory, days=30, days_ago=0):
    dt = datetime.datetime.now()
    UnixTime = int(time.mktime(dt.timetuple()))
    #web variables
    url = 'https://query1.finance.yahoo.com/v8/finance/chart/'+symbol+'?period1='+str(UnixTime-86400*(days+days_ago))+'&period2='+str(UnixTime-86400*days_ago)+'&interval=5m&indicators=quote%7Csma~60%7Cmfi~8&includePrePost=true&events=div%7Csplit%7Cearn&lang=en-CA&region=CA&corsDomain=ca.finance.yahoo.com'
    #proxies
    http_proxy  = ''
    https_proxy = ''
    ftp_proxy   = ''
    proxyDict = { 
                  "http"  : http_proxy, 
                  "https" : https_proxy, 
                  "ftp"   : ftp_proxy
                }

    hdr = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.101 Safari/537.36',
       'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
       'Connection': 'keep-alive'}
    
    try:
        resp = requests.get(url, headers=hdr)
        if resp.status_code != 200:
            # This means something went wrong.
            print(resp.status_code)
        data = json.loads(resp.text)
        #json unpack
        timestamp_raw = data['chart']['result'][0]['timestamp']
        timestamp = [datetime.datetime.fromtimestamp(x).strftime('%Y%m%d-%H%M') for x in timestamp_raw]
       
        quote = data['chart']['result'][0]['indicators']['quote'][0]
        stock_df = pd.DataFrame(quote)
        #index is symbol and timestamp
        stock_df.index = [str(x) for x in timestamp]
        
        #ensure only active market minutes are downloaded
        HourMinute = [datetime.datetime.fromtimestamp(x).strftime('%H%M') for x in timestamp_raw]
        stock_df['HourMinute'] = HourMinute
        stock_df['HourMinute'] = stock_df['HourMinute'].apply(pd.to_numeric)
        stock_df = stock_df[(stock_df['HourMinute'] >= 930) & (stock_df['HourMinute'] < 1600)]
        
        #MFI(14)
        MFI = data['chart']['result'][0]['indicators']['mfi'][0]['mfi']
        stock_df['MFI'] = MFI
        
        #moving averages
        stock_df['vol20'] = stock_df['volume'].rolling(window=20).mean()
        stock_df['sma5'] = stock_df['close'].rolling(window=5).mean()
        stock_df['sma8'] = stock_df['close'].rolling(window=8).mean()
        stock_df['sma13'] = stock_df['close'].rolling(window=13).mean()
        stock_df['sma21'] = stock_df['close'].rolling(window=21).mean()

        #MACD (9,12,26)
        stock_df['ewm26'] = stock_df['close'].ewm(span=26,min_periods=0,adjust=False,ignore_na=False).mean()
        stock_df['ewm12'] = stock_df['close'].ewm(span=12,min_periods=0,adjust=False,ignore_na=False).mean()
        stock_df['MACD'] = stock_df['ewm12']-stock_df['ewm26']
        stock_df['MACD_signal'] = stock_df['MACD'].ewm(span=9,min_periods=0,adjust=False,ignore_na=False).mean()
        stock_df['MACD_pos_neg'] = stock_df['MACD']-stock_df['MACD_signal']

        #stock_df.drop(['close', 'high', 'low', 'open','volume','sma','vol20'], axis=1, inplace=True)
        stock_df = stock_df.dropna()
        stock_df = stock_df[~(stock_df == np.inf).any(axis=1)]
        if len(stock_df) != 0:
            stock_df.to_csv('{}{}.csv'.format(directory,symbol[:4]))
        try:
            lock.acquire()
            #clear memory
            gc.collect()
        finally:
            lock.release()
        
    except Exception:
        print(symbol)
        print(traceback.format_exc())
        # or
        print(sys.exc_info()[2])

# %%
#Delete files in Directory
directory = './data5m/'
filelist = [ f for f in os.listdir(directory) if f.endswith(".csv") ]
for f in filelist:
    os.remove(os.path.join(directory, f))

# %%
if __name__ == '__main__':

    #start timer
    start = timeit.default_timer()

    symbolslist = open('symbolsIntraD.txt').read().split('\n')

    directory = './data5m/'

    threadlist = []

    for u in symbolslist:

        t = threading.Thread(target = symbol_downloader_intraday,args=(u,directory))
        t.start()
        threadlist.append(t)
        #sets top limit of active threads to 20
        while threading.activeCount()>20:
            a=0
        #print threading.activeCount()

    for b in threadlist:
        b.join()
    print ("# of threads: ", len(threadlist))
# Out:
# 404
#
# Traceback (most recent call last):
#   File "<ipython-input-237-25cb17111d25>", line 27, in symbol_downloader_intraday
#     timestamp_raw = data['chart']['result'][0]['timestamp']
# IndexError: list index out of range
#
# <traceback object at 0x000001FD9205DA48>
# # of threads:  132

# %%
#IntraDay Buy-In signal @5m candle sticks
gc.collect()
to_send = ''
directory = './data5m/'
# get list with filenames in folder and throw away all non ncsv
files = [f for f in os.listdir(directory) if f.endswith('.csv')]
for f in files:
    try:
        ticker_df = pd.read_csv(os.path.join(directory, f))
        jones_df = pd.read_csv(os.path.join(directory,'^DJI.csv'))
        
        stock_df = pd.merge(ticker_df, jones_df, left_index=True, right_index=True)
        
        for i in range(int((len(stock_df)*0.3))): #engulfing candel pattern looping through all available data 
            
            window = 59 #number of days back from today to look at for slope
            
            i += 1 #start range from 1 instead of 0
            
            open0 =  float(stock_df['open_x'].iloc[-i])
            close0 =  float(stock_df['close_x'].iloc[-i])
            open_1 = float(stock_df['open_x'].iloc[-(i+1)])
            close_1 = float(stock_df['close_x'].iloc[-(i+1)])
            
            #Moving averages
            sma5 = float(stock_df['sma5_x'].iloc[-i])
            sma8 = float(stock_df['sma8_x'].iloc[-i])
            sma13 = float(stock_df['sma13_x'].iloc[-i])
            sma21 = float(stock_df['sma21_x'].iloc[-i])
            
            sma5_1 = float(stock_df['sma5_x'].iloc[-(i+1)])
            sma8_1 = float(stock_df['sma8_x'].iloc[-(i+1)])
            sma13_1 = float(stock_df['sma13_x'].iloc[-(i+1)])
            sma21_1 = float(stock_df['sma21_x'].iloc[-(i+1)])
            
            sma5_2 = float(stock_df['sma5_x'].iloc[-(i+2)])
            sma8_2 = float(stock_df['sma8_x'].iloc[-(i+2)])
            sma13_2 = float(stock_df['sma13_x'].iloc[-(i+2)])
            sma21_2 = float(stock_df['sma21_x'].iloc[-(i+2)])  
            
            #Money Flow Index
            MFI = float(stock_df['MFI_x'].iloc[-i])
            
#             #MACD
#             MACD_pos_neg = float(stock_df['MACD_pos_neg_x'].iloc[-i])
#             MACD_pos_neg_1 = float(stock_df['MACD_pos_neg_x'].iloc[-(i+1)])
            
            #moving average momentum indicators
            s5 =  ((sma5-sma5_1)/sma5)*1000
            s8 =  ((sma8-sma8_1)/sma8)*1000
            s13 =  ((sma13-sma13_1)/sma13)*1000
            s21 =  ((sma21-sma21_1)/sma21)*1000
            
            z5 =  ((sma5_1-sma5_2)/sma5_1)*1000
            z8 =  ((sma8_1-sma8_2)/sma8_1)*1000
            z13 =  ((sma13_1-sma13_2)/sma13_1)*1000
            z21 =  ((sma21_1-sma21_2)/sma21_1)*1000
            
            #volume indicators
            mktVlcty0 = float(stock_df['volume_x'].iloc[-i])*float(stock_df['close_x'].iloc[-i])
            
            volume0 = (float(stock_df['volume_x'].iloc[-i])+0.001)/(float(stock_df['vol20_x'].iloc[-i])+0.001)
            
            #market indexes
            j_open0 =  float(stock_df['open_y'].iloc[-i])
            j_close0 =  float(stock_df['close_y'].iloc[-i])
            stockPChange = (close0-open0)/open0 
            jonesPChange = (j_close0-j_open0)/j_open0
            
            #time of day
            timeOfDay = stock_df['Unnamed: 0_x'].iloc[-i][-4:]
            date0 = stock_df['Unnamed: 0_x'].iloc[-i][:8]
            tday_date = str(datetime.datetime.today().strftime('%Y%m%d'))

            #core logic
            if  stockPChange > abs(jonesPChange)*10\
                and open0 < close0 \
                and s5 >= z5 and s8 >= z8 and s13 >= z13 and s21 >= z21\
                and s5 > 0 and s8 > 0 and s13 > 0 and s21 > 0\
                and mktVlcty0 > 200000\
                and volume0 >= 2\
                and timeOfDay != '0930':
                #and date0 == tday_date:

                to_send += '{} has 5m buy-in signal with high volume on {}, and is under $5. Close price: {} \n'.format(f[:-4],(stock_df['Unnamed: 0_x'].iloc[-i]),close0)
            
            #plateau signal
            if  s5 >= z5 and s8 >= z8 and s13 >= z13 and s21 >= z21\
                and s5 < 0 and s8 < 0 and s13 < 0 and s21 < 0 \
                and mktVlcty0 >100000 \
                and timeOfDay != '0930':
                #and date0 == tday_date:

                to_send += '{} has 5m plateau signal with high volume on {}, and is under $5. Close price: {} \n'.format(f[:-4],(stock_df['Unnamed: 0_x'].iloc[-i]),close0)

            #MFI buy
            if  MFI < 20 \
                and mktVlcty0 >200000 \
                and open0 < close0 \
                and timeOfDay != '0930':
                #and date0 == tday_date:

                to_send += '{} has 5m MFI buy signal with high volume on {}, and is under $5. Close price: {} \n'.format(f[:-4],(stock_df['Unnamed: 0_x'].iloc[-i]),close0)
            
            #MFI sell
            if  MFI > 80 \
                and open0 > close0 \
                and mktVlcty0 >200000 \
                and timeOfDay != '0930':
                #and date0 == tday_date:

                to_send += '{} has 5m MFI sell signal with high volume on {}, and is under $5. Close price: {} \n'.format(f[:-4],(stock_df['Unnamed: 0_x'].iloc[-i]),close0)


    except IndexError:
        print("{} has too few rows".format(f))
        pass
    except Exception:
        print(traceback.format_exc())
        # or
        print(sys.exc_info()[2])

# %%
print (to_send)
# Out:
# ADMP has 5m buy-in signal with high volume on 20200608-1535, and is under $5. Close price: 0.6600000262260437
# ADMP has 5m buy-in signal with high volume on 20200608-1405, and is under $5. Close price: 0.621999979019165
# AHT has 5m buy-in signal with high volume on 20200610-1415, and is under $5. Close price: 1.2649999856948853
# AHT has 5m plateau signal with high volume on 20200610-1005, and is under $5. Close price: 1.2799999713897705
# AHT has 5m plateau signal with high volume on 20200609-0945, and is under $5. Close price: 1.6444000005722046
# AHT has 5m buy-in signal with high volume on 20200608-1240, and is under $5. Close price: 1.75
# AHT has 5m MFI sell signal with high volume on 20200608-1040, and is under $5. Close price: 1.6332000494003296
# AHT has 5m buy-in signal with high volume on 20200608-1030, and is under $5. Close price: 1.55840003490448
# AHT has 5m buy-in signal with high volume on 20200605-0950, and is under $5. Close price: 1.2036999464035034
# AHT has 5m buy-in signal with high volume on 20200605-0935, and is under $5. Close price: 1.1349999904632568
# AHT has 5m buy-in signal with high volume on 20200604-1420, and is under $5. Close price: 0.9243999719619752
# AI has 5m plateau signal with high volume on 20200609-1020, and is under $5. Close price: 3.428999900817871
# AI has 5m plateau signal with high volume on 20200609-1010, and is under $5. Close price: 3.390000104904175
# AI has 5m buy-in signal with high volume on 20200605-1220, and is under $5. Close price: 3.3499999046325684
# AI has 5m buy-in signal with high volume on 20200604-1335, and is under $5. Close price: 2.9300000667572017
# ALJJ has 5m buy-in signal with high volume on 20200609-1530, and is under $5. Close price: 0.8799999952316284
# ALJJ has 5m buy-in signal with high volume on 20200609-1520, and is under $5. Close price: 0.8725379705429077
# ARLP has 5m plateau signal with high volume on 20200610-0945, and is under $5. Close price: 4.25
# ARLP has 5m buy-in signal with high volume on 20200609-1510, and is under $5. Close price: 4.4099998474121085
# ARLP has 5m plateau signal with high volume on 20200609-1405, and is under $5. Close price: 4.309999942779541
# ARLP has 5m plateau signal with high volume on 20200609-1040, and is under $5. Close price: 4.510000228881836
# ARLP has 5m plateau signal with high volume on 20200609-1010, and is under $5. Close price: 4.531000137329102
# ARLP has 5m MFI sell signal with high volume on 20200608-1015, and is under $5. Close price: 4.710000038146973
# ARLP has 5m MFI sell signal with high volume on 20200608-1010, and is under $5. Close price: 4.840099811553955
# ARLP has 5m buy-in signal with high volume on 20200608-0945, and is under $5. Close price: 4.5900001525878915
# ARLP has 5m buy-in signal with high volume on 20200608-0935, and is under $5. Close price: 4.389999866485597
# ARLP has 5m MFI sell signal with high volume on 20200605-0955, and is under $5. Close price: 3.7999999523162837
# ARLP has 5m buy-in signal with high volume on 20200605-0950, and is under $5. Close price: 3.849999904632568
# ARLP has 5m buy-in signal with high volume on 20200605-0945, and is under $5. Close price: 3.7300000190734863
# ARLP has 5m buy-in signal with high volume on 20200605-0940, and is under $5. Close price: 3.690000057220459
# ARLP has 5m MFI sell signal with high volume on 20200604-1035, and is under $5. Close price: 3.4600000381469727
# ARLP has 5m buy-in signal with high volume on 20200604-1015, and is under $5. Close price: 3.390000104904175
# ARLP has 5m buy-in signal with high volume on 20200604-1000, and is under $5. Close price: 3.309999942779541
# AVGR has 5m plateau signal with high volume on 20200610-0940, and is under $5. Close price: 0.5845999717712402
# AVGR has 5m plateau signal with high volume on 20200610-0935, and is under $5. Close price: 0.5702000260353088
# AVGR has 5m MFI buy signal with high volume on 20200610-0935, and is under $5. Close price: 0.5702000260353088
# AVGR has 5m buy-in signal with high volume on 20200609-1520, and is under $5. Close price: 0.6399000287055969
# AVGR has 5m buy-in signal with high volume on 20200609-1035, and is under $5. Close price: 0.6100000143051147
# AVGR has 5m buy-in signal with high volume on 20200609-1030, and is under $5. Close price: 0.5583999752998352
# AVGR has 5m buy-in signal with high volume on 20200609-0940, and is under $5. Close price: 0.5144990086555481
# BBI has 5m buy-in signal with high volume on 20200610-1235, and is under $5. Close price: 1.5299999713897705
# BGG has 5m plateau signal with high volume on 20200610-1025, and is under $5. Close price: 2.0899999141693115
# BGG has 5m MFI buy signal with high volume on 20200610-1025, and is under $5. Close price: 2.0899999141693115
# BGG has 5m plateau signal with high volume on 20200610-1015, and is under $5. Close price: 2.147900104522705
# BGG has 5m MFI buy signal with high volume on 20200610-1015, and is under $5. Close price: 2.147900104522705
# BGG has 5m plateau signal with high volume on 20200609-1010, and is under $5. Close price: 2.559999942779541
# BGG has 5m plateau signal with high volume on 20200609-0955, and is under $5. Close price: 2.619999885559082
# BGG has 5m MFI sell signal with high volume on 20200608-1325, and is under $5. Close price: 2.7100000381469727
# BGG has 5m buy-in signal with high volume on 20200608-1315, and is under $5. Close price: 2.75
# BGG has 5m buy-in signal with high volume on 20200608-1310, and is under $5. Close price: 2.677299976348877
# BGG has 5m buy-in signal with high volume on 20200608-1300, and is under $5. Close price: 2.609999895095825
# BGG has 5m buy-in signal with high volume on 20200608-1250, and is under $5. Close price: 2.5399000644683842
# BGG has 5m buy-in signal with high volume on 20200605-1425, and is under $5. Close price: 2.440000057220459
# BGG has 5m buy-in signal with high volume on 20200605-1350, and is under $5. Close price: 2.220000028610229
# BGG has 5m buy-in signal with high volume on 20200605-1220, and is under $5. Close price: 2.0682001113891597
# BGG has 5m MFI sell signal with high volume on 20200605-1200, and is under $5. Close price: 2.009999990463257
# BGG has 5m buy-in signal with high volume on 20200605-1155, and is under $5. Close price: 2.0199999809265137
# BGG has 5m buy-in signal with high volume on 20200605-1045, and is under $5. Close price: 1.9337999820709229
# BGG has 5m buy-in signal with high volume on 20200604-1010, and is under $5. Close price: 1.7849999666213991
# BGG has 5m buy-in signal with high volume on 20200603-1350, and is under $5. Close price: 1.7450000047683716
# BGG has 5m buy-in signal with high volume on 20200603-1210, and is under $5. Close price: 1.6799999475479126
# BIOL has 5m MFI sell signal with high volume on 20200610-1510, and is under $5. Close price: 0.5884490013122559
# BIOL has 5m MFI sell signal with high volume on 20200610-1345, and is under $5. Close price: 0.5759999752044678
# BIOL has 5m buy-in signal with high volume on 20200610-1340, and is under $5. Close price: 0.5805000066757202
# BIOL has 5m buy-in signal with high volume on 20200610-1320, and is under $5. Close price: 0.5635010004043579
# BIOL has 5m MFI sell signal with high volume on 20200610-1315, and is under $5. Close price: 0.5600000023841858
# BIOL has 5m buy-in signal with high volume on 20200610-1310, and is under $5. Close price: 0.5601000189781189
# BIOL has 5m plateau signal with high volume on 20200608-1540, and is under $5. Close price: 0.5450000166893005
# BIOL has 5m plateau signal with high volume on 20200608-1350, and is under $5. Close price: 0.5564000010490417
# BIOL has 5m MFI sell signal with high volume on 20200605-1300, and is under $5. Close price: 0.7184000015258789
# BIOL has 5m buy-in signal with high volume on 20200605-1255, and is under $5. Close price: 0.7288990020751953
# BIOL has 5m MFI sell signal with high volume on 20200605-1245, and is under $5. Close price: 0.6800000071525574
# BIOL has 5m buy-in signal with high volume on 20200605-1235, and is under $5. Close price: 0.7028999924659729
# BIOL has 5m MFI sell signal with high volume on 20200605-1045, and is under $5. Close price: 0.7149999737739563
# BIOL has 5m MFI sell signal with high volume on 20200605-1040, and is under $5. Close price: 0.7311999797821045
# BIOL has 5m buy-in signal with high volume on 20200605-1035, and is under $5. Close price: 0.732200026512146
# BIOL has 5m buy-in signal with high volume on 20200605-1030, and is under $5. Close price: 0.6678000092506409
# BIOL has 5m buy-in signal with high volume on 20200605-1020, and is under $5. Close price: 0.6190000176429749
# CCLP has 5m buy-in signal with high volume on 20200608-1015, and is under $5. Close price: 1.4950000047683716
# CCO has 5m buy-in signal with high volume on 20200609-1500, and is under $5. Close price: 1.399999976158142
# CCO has 5m MFI sell signal with high volume on 20200608-1505, and is under $5. Close price: 1.5399999618530271
# CCO has 5m buy-in signal with high volume on 20200608-1445, and is under $5. Close price: 1.5499999523162842
# CCO has 5m buy-in signal with high volume on 20200608-1425, and is under $5. Close price: 1.5099999904632568
# CCO has 5m MFI sell signal with high volume on 20200608-0950, and is under $5. Close price: 1.5700000524520874
# CCO has 5m buy-in signal with high volume on 20200608-0940, and is under $5. Close price: 1.6089999675750732
# CCO has 5m buy-in signal with high volume on 20200605-1555, and is under $5. Close price: 1.2999999523162842
# CCO has 5m MFI sell signal with high volume on 20200605-1240, and is under $5. Close price: 1.344499945640564
# CCO has 5m buy-in signal with high volume on 20200605-1205, and is under $5. Close price: 1.2201000452041626
# CCO has 5m MFI sell signal with high volume on 20200605-1055, and is under $5. Close price: 1.1299999952316284
# CCO has 5m buy-in signal with high volume on 20200605-1040, and is under $5. Close price: 1.1649999618530271
# CCO has 5m buy-in signal with high volume on 20200605-0945, and is under $5. Close price: 1.0901000499725342
# CCO has 5m buy-in signal with high volume on 20200605-0940, and is under $5. Close price: 1.0700000524520874
# CCO has 5m buy-in signal with high volume on 20200605-0935, and is under $5. Close price: 1.0399999618530271
# CCO has 5m plateau signal with high volume on 20200604-1335, and is under $5. Close price: 0.9684000015258788
# CDEV has 5m MFI buy signal with high volume on 20200610-1505, and is under $5. Close price: 1.565000057220459
# CDEV has 5m MFI sell signal with high volume on 20200610-1205, and is under $5. Close price: 1.6749999523162842
# CDEV has 5m MFI sell signal with high volume on 20200610-1155, and is under $5. Close price: 1.6734999418258667
# CDEV has 5m MFI sell signal with high volume on 20200610-1125, and is under $5. Close price: 1.5750000476837158
# CDEV has 5m MFI buy signal with high volume on 20200610-1005, and is under $5. Close price: 1.4643000364303589
# CDEV has 5m plateau signal with high volume on 20200610-1000, and is under $5. Close price: 1.4500000476837158
# CDEV has 5m MFI buy signal with high volume on 20200610-1000, and is under $5. Close price: 1.4500000476837158
# CDEV has 5m MFI buy signal with high volume on 20200610-0955, and is under $5. Close price: 1.4199999570846558
# CDEV has 5m plateau signal with high volume on 20200610-0945, and is under $5. Close price: 1.445199966430664
# CDEV has 5m MFI buy signal with high volume on 20200610-0945, and is under $5. Close price: 1.445199966430664
# CDEV has 5m plateau signal with high volume on 20200610-0935, and is under $5. Close price: 1.4850000143051147
# CDEV has 5m MFI buy signal with high volume on 20200610-0935, and is under $5. Close price: 1.4850000143051147
# CDEV has 5m plateau signal with high volume on 20200609-1515, and is under $5. Close price: 1.7699999809265137
# CDEV has 5m MFI buy signal with high volume on 20200609-1425, and is under $5. Close price: 1.7999999523162842
# CDEV has 5m buy-in signal with high volume on 20200609-1335, and is under $5. Close price: 1.870000004768372
# CDEV has 5m MFI sell signal with high volume on 20200609-1055, and is under $5. Close price: 1.8600000143051147
# CDEV has 5m plateau signal with high volume on 20200609-0935, and is under $5. Close price: 1.8798999786376955
# CDEV has 5m MFI buy signal with high volume on 20200608-1050, and is under $5. Close price: 1.9098999500274656
# CDEV has 5m MFI sell signal with high volume on 20200608-1015, and is under $5. Close price: 2.0562999248504643
# CDEV has 5m MFI buy signal with high volume on 20200605-1520, and is under $5. Close price: 1.4299999475479126
# CDEV has 5m MFI buy signal with high volume on 20200605-1515, and is under $5. Close price: 1.4076999425888062
# CDEV has 5m MFI sell signal with high volume on 20200605-1455, and is under $5. Close price: 1.4686000347137451
# CDEV has 5m MFI sell signal with high volume on 20200605-1450, and is under $5. Close price: 1.4700000286102295
# CDEV has 5m buy-in signal with high volume on 20200605-1425, and is under $5. Close price: 1.4499000310897827
# CDEV has 5m MFI sell signal with high volume on 20200605-1335, and is under $5. Close price: 1.4149999618530271
# CDEV has 5m MFI sell signal with high volume on 20200605-1325, and is under $5. Close price: 1.4099999666213991
# CDEV has 5m buy-in signal with high volume on 20200605-1155, and is under $5. Close price: 1.2898999452590942
# CDEV has 5m MFI sell signal with high volume on 20200605-1120, and is under $5. Close price: 1.25
# CDEV has 5m MFI sell signal with high volume on 20200605-1115, and is under $5. Close price: 1.2599999904632568
# CDEV has 5m buy-in signal with high volume on 20200605-0945, and is under $5. Close price: 1.268100023269653
# CDEV has 5m buy-in signal with high volume on 20200605-0940, and is under $5. Close price: 1.2400000095367432
# CDEV has 5m buy-in signal with high volume on 20200604-1550, and is under $5. Close price: 1.149999976158142
# CDEV has 5m plateau signal with high volume on 20200604-1530, and is under $5. Close price: 1.125
# CDEV has 5m MFI sell signal with high volume on 20200604-1335, and is under $5. Close price: 1.1349999904632568
# CDEV has 5m buy-in signal with high volume on 20200604-1325, and is under $5. Close price: 1.147699952125549
# CDEV has 5m buy-in signal with high volume on 20200604-1315, and is under $5. Close price: 1.1299999952316284
# CDEV has 5m buy-in signal with high volume on 20200604-1255, and is under $5. Close price: 1.1050000190734863
# CDEV has 5m buy-in signal with high volume on 20200604-1250, and is under $5. Close price: 1.0900000333786009
# CDEV has 5m buy-in signal with high volume on 20200603-1525, and is under $5. Close price: 1.1299999952316284
# CDEV has 5m buy-in signal with high volume on 20200603-1435, and is under $5. Close price: 1.1200000047683716
# CEIX has 5m plateau signal with high volume on 20200610-0945, and is under $5. Close price: 9.154999732971193
# CEIX has 5m plateau signal with high volume on 20200609-1210, and is under $5. Close price: 9.579999923706056
# CEIX has 5m buy-in signal with high volume on 20200608-1550, and is under $5. Close price: 9.800000190734863
# CEIX has 5m plateau signal with high volume on 20200608-1355, and is under $5. Close price: 9.06999969482422
# CEIX has 5m buy-in signal with high volume on 20200608-1000, and is under $5. Close price: 9.029999732971193
# CEIX has 5m MFI sell signal with high volume on 20200605-1555, and is under $5. Close price: 8.149999618530272
# CETX has 5m plateau signal with high volume on 20200610-1410, and is under $5. Close price: 2.3199000358581543
# CETX has 5m plateau signal with high volume on 20200610-1345, and is under $5. Close price: 2.325000047683716
# CETX has 5m MFI buy signal with high volume on 20200610-1335, and is under $5. Close price: 2.3257999420166016
# CETX has 5m plateau signal with high volume on 20200610-1030, and is under $5. Close price: 2.3050000667572017
# CETX has 5m MFI buy signal with high volume on 20200610-1000, and is under $5. Close price: 2.45009994506836
# CETX has 5m plateau signal with high volume on 20200610-0955, and is under $5. Close price: 2.450000047683716
# CETX has 5m MFI buy signal with high volume on 20200609-1355, and is under $5. Close price: 3.0799999237060547
# CETX has 5m MFI sell signal with high volume on 20200609-1040, and is under $5. Close price: 3.312700033187866
# CETX has 5m buy-in signal with high volume on 20200609-1030, and is under $5. Close price: 3.365000009536743
# CETX has 5m MFI sell signal with high volume on 20200609-1000, and is under $5. Close price: 2.630000114440918
# CETX has 5m buy-in signal with high volume on 20200609-0950, and is under $5. Close price: 2.5801000595092773
# CETX has 5m MFI sell signal with high volume on 20200609-0945, and is under $5. Close price: 2.400000095367432
# CETX has 5m buy-in signal with high volume on 20200609-0940, and is under $5. Close price: 2.451200008392334
# CETX has 5m buy-in signal with high volume on 20200609-0935, and is under $5. Close price: 2.25
# CETX has 5m MFI buy signal with high volume on 20200608-1020, and is under $5. Close price: 2.0299999713897705
# CLUB has 5m buy-in signal with high volume on 20200609-1510, and is under $5. Close price: 1.190000057220459
# CLUB has 5m buy-in signal with high volume on 20200609-1155, and is under $5. Close price: 1.1200000047683716
# CLUB has 5m buy-in signal with high volume on 20200609-1120, and is under $5. Close price: 1.0198999643325806
# CNHI has 5m plateau signal with high volume on 20200610-1350, and is under $5. Close price: 7.568999767303468
# CNHI has 5m MFI buy signal with high volume on 20200610-1035, and is under $5. Close price: 7.679999828338622
# CNHI has 5m plateau signal with high volume on 20200610-1025, and is under $5. Close price: 7.605000019073486
# CNHI has 5m plateau signal with high volume on 20200610-0955, and is under $5. Close price: 7.755899906158447
# CNHI has 5m MFI buy signal with high volume on 20200610-0955, and is under $5. Close price: 7.755899906158447
# CNHI has 5m MFI buy signal with high volume on 20200610-0950, and is under $5. Close price: 7.699999809265138
# CNHI has 5m plateau signal with high volume on 20200609-1545, and is under $5. Close price: 8.034199714660645
# CNHI has 5m MFI buy signal with high volume on 20200609-1515, and is under $5. Close price: 8.057083129882812
# CNHI has 5m plateau signal with high volume on 20200609-1450, and is under $5. Close price: 8.074999809265138
# CNHI has 5m MFI buy signal with high volume on 20200609-1445, and is under $5. Close price: 8.074999809265138
# CNHI has 5m plateau signal with high volume on 20200609-1435, and is under $5. Close price: 8.104999542236326
# CNHI has 5m MFI buy signal with high volume on 20200609-1435, and is under $5. Close price: 8.104999542236326
# CNHI has 5m plateau signal with high volume on 20200609-1020, and is under $5. Close price: 7.980000019073486
# CNHI has 5m plateau signal with high volume on 20200609-1010, and is under $5. Close price: 7.949999809265138
# CNHI has 5m MFI sell signal with high volume on 20200609-0940, and is under $5. Close price: 8.131699562072754
# CNHI has 5m buy-in signal with high volume on 20200608-1555, and is under $5. Close price: 8.140000343322754
# CNHI has 5m MFI sell signal with high volume on 20200608-1520, and is under $5. Close price: 8.034999847412111
# CNHI has 5m buy-in signal with high volume on 20200608-1510, and is under $5. Close price: 8.050000190734862
# CNHI has 5m MFI sell signal with high volume on 20200608-1430, and is under $5. Close price: 7.985000133514403
# CNHI has 5m MFI sell signal with high volume on 20200608-1150, and is under $5. Close price: 7.864999771118164
# CNHI has 5m MFI sell signal with high volume on 20200608-1130, and is under $5. Close price: 7.829999923706055
# CNHI has 5m MFI sell signal with high volume on 20200608-1125, and is under $5. Close price: 7.869999885559082
# CNHI has 5m buy-in signal with high volume on 20200608-1120, and is under $5. Close price: 7.90500020980835
# CNHI has 5m MFI sell signal with high volume on 20200608-1115, and is under $5. Close price: 7.84499979019165
# CNHI has 5m MFI sell signal with high volume on 20200608-1105, and is under $5. Close price: 7.855000019073486
# CNHI has 5m MFI buy signal with high volume on 20200608-1040, and is under $5. Close price: 7.760000228881836
# CNHI has 5m plateau signal with high volume on 20200605-1550, and is under $5. Close price: 7.619999885559082
# CNHI has 5m plateau signal with high volume on 20200605-1445, and is under $5. Close price: 7.71999979019165
# CNHI has 5m plateau signal with high volume on 20200605-1435, and is under $5. Close price: 7.7150001525878915
# CNHI has 5m MFI sell signal with high volume on 20200605-0945, and is under $5. Close price: 7.705800056457519
# CNHI has 5m buy-in signal with high volume on 20200604-1545, and is under $5. Close price: 7.125
# CNHI has 5m MFI buy signal with high volume on 20200604-1000, and is under $5. Close price: 7.085000038146973
# CNHI has 5m MFI buy signal with high volume on 20200604-0955, and is under $5. Close price: 7.057499885559082
# CNHI has 5m plateau signal with high volume on 20200604-0950, and is under $5. Close price: 7.059999942779541
# CNHI has 5m MFI buy signal with high volume on 20200604-0950, and is under $5. Close price: 7.059999942779541
# CNHI has 5m MFI buy signal with high volume on 20200604-0940, and is under $5. Close price: 7.0250000953674325
# CNHI has 5m buy-in signal with high volume on 20200603-1525, and is under $5. Close price: 7.204999923706055
# CNHI has 5m MFI sell signal with high volume on 20200603-1440, and is under $5. Close price: 7.164999961853027
# CNHI has 5m plateau signal with high volume on 20200603-1225, and is under $5. Close price: 7.114999771118164
# CNHI has 5m MFI sell signal with high volume on 20200603-1135, and is under $5. Close price: 7.1599998474121085
# CNHI has 5m buy-in signal with high volume on 20200603-1030, and is under $5. Close price: 7.125
# CPE has 5m MFI buy signal with high volume on 20200610-1505, and is under $5. Close price: 1.7749999761581419
# CPE has 5m MFI buy signal with high volume on 20200610-1455, and is under $5. Close price: 1.7849999666213991
# CPE has 5m MFI sell signal with high volume on 20200610-1205, and is under $5. Close price: 1.8375999927520752
# CPE has 5m plateau signal with high volume on 20200610-1020, and is under $5. Close price: 1.440000057220459
# CPE has 5m plateau signal with high volume on 20200610-1005, and is under $5. Close price: 1.5199999809265137
# CPE has 5m MFI buy signal with high volume on 20200610-1005, and is under $5. Close price: 1.5199999809265137
# CPE has 5m plateau signal with high volume on 20200609-1515, and is under $5. Close price: 1.8849999904632568
# CPE has 5m plateau signal with high volume on 20200609-1510, and is under $5. Close price: 1.861999988555908
# CPE has 5m plateau signal with high volume on 20200609-1425, and is under $5. Close price: 1.924999952316284
# CPE has 5m MFI buy signal with high volume on 20200609-1425, and is under $5. Close price: 1.924999952316284
# CPE has 5m plateau signal with high volume on 20200609-1410, and is under $5. Close price: 1.9299999475479128
# CPE has 5m plateau signal with high volume on 20200609-1320, and is under $5. Close price: 1.9700000286102293
# CPE has 5m plateau signal with high volume on 20200609-1300, and is under $5. Close price: 2.0050001144409184
# CPE has 5m plateau signal with high volume on 20200609-1240, and is under $5. Close price: 2.0350000858306885
# CPE has 5m MFI sell signal with high volume on 20200609-1055, and is under $5. Close price: 2.0799000263214107
# CPE has 5m MFI sell signal with high volume on 20200609-1050, and is under $5. Close price: 2.075000047683716
# CPE has 5m plateau signal with high volume on 20200609-1020, and is under $5. Close price: 1.919999957084656
# CPE has 5m plateau signal with high volume on 20200609-1015, and is under $5. Close price: 1.8875999450683596
# CPE has 5m plateau signal with high volume on 20200609-0935, and is under $5. Close price: 2.150000095367432
# CPE has 5m plateau signal with high volume on 20200608-1435, and is under $5. Close price: 2.316699981689453
# CPE has 5m MFI buy signal with high volume on 20200608-1300, and is under $5. Close price: 2.450000047683716
# CPE has 5m buy-in signal with high volume on 20200608-1220, and is under $5. Close price: 2.6600000858306885
# CPE has 5m MFI sell signal with high volume on 20200608-1155, and is under $5. Close price: 2.199899911880493
# CPE has 5m buy-in signal with high volume on 20200608-1150, and is under $5. Close price: 2.244999885559082
# CPE has 5m MFI sell signal with high volume on 20200608-1140, and is under $5. Close price: 2.124599933624268
# CPE has 5m MFI sell signal with high volume on 20200608-0945, and is under $5. Close price: 2.0380001068115234
# CPE has 5m buy-in signal with high volume on 20200608-0935, and is under $5. Close price: 2.039999961853028
# CPE has 5m buy-in signal with high volume on 20200605-1555, and is under $5. Close price: 1.3600000143051147
# CPE has 5m plateau signal with high volume on 20200605-1430, and is under $5. Close price: 1.2899999618530271
# CPE has 5m MFI buy signal with high volume on 20200605-1430, and is under $5. Close price: 1.2899999618530271
# CPE has 5m MFI buy signal with high volume on 20200605-1410, and is under $5. Close price: 1.3184000253677368
# CPE has 5m MFI sell signal with high volume on 20200605-1335, and is under $5. Close price: 1.3885999917984009
# CPE has 5m MFI sell signal with high volume on 20200605-1330, and is under $5. Close price: 1.4177999496459959
# CPE has 5m MFI sell signal with high volume on 20200605-1200, and is under $5. Close price: 1.2599999904632568
# CPE has 5m MFI sell signal with high volume on 20200605-1155, and is under $5. Close price: 1.3600000143051147
# CPE has 5m buy-in signal with high volume on 20200605-1150, and is under $5. Close price: 1.3650000095367432
# CPE has 5m buy-in signal with high volume on 20200605-1145, and is under $5. Close price: 1.2999999523162842
# CPE has 5m MFI sell signal with high volume on 20200605-1140, and is under $5. Close price: 1.2400000095367432
# CPE has 5m buy-in signal with high volume on 20200605-1125, and is under $5. Close price: 1.2200000286102295
# CPE has 5m MFI buy signal with high volume on 20200605-1045, and is under $5. Close price: 1.1349999904632568
# CPE has 5m MFI sell signal with high volume on 20200605-0955, and is under $5. Close price: 1.1299999952316284
# CPE has 5m MFI sell signal with high volume on 20200605-0945, and is under $5. Close price: 1.100000023841858
# CPE has 5m MFI sell signal with high volume on 20200605-0940, and is under $5. Close price: 1.100100040435791
# CPE has 5m MFI sell signal with high volume on 20200605-0935, and is under $5. Close price: 1.1200000047683716
# CPE has 5m MFI sell signal with high volume on 20200604-1225, and is under $5. Close price: 0.8069000244140625
# CPE has 5m MFI sell signal with high volume on 20200604-1215, and is under $5. Close price: 0.8072999715805054
# CPE has 5m MFI sell signal with high volume on 20200604-1030, and is under $5. Close price: 0.7736999988555908
# CPE has 5m plateau signal with high volume on 20200604-0955, and is under $5. Close price: 0.7598000168800354
# CPE has 5m plateau signal with high volume on 20200604-0940, and is under $5. Close price: 0.7600100040435791
# CPE has 5m plateau signal with high volume on 20200603-1555, and is under $5. Close price: 0.7915999889373779
# CPE has 5m MFI buy signal with high volume on 20200603-1555, and is under $5. Close price: 0.7915999889373779
# CPE has 5m buy-in signal with high volume on 20200603-1510, and is under $5. Close price: 0.8084999918937683
# CPE has 5m plateau signal with high volume on 20200603-1240, and is under $5. Close price: 0.7858999967575073
# CPE has 5m plateau signal with high volume on 20200603-1230, and is under $5. Close price: 0.7897989749908447
# CPE has 5m plateau signal with high volume on 20200603-1200, and is under $5. Close price: 0.7935000061988831
# CPE has 5m MFI buy signal with high volume on 20200603-1105, and is under $5. Close price: 0.8108000159263611
# CPE has 5m MFI buy signal with high volume on 20200603-1100, and is under $5. Close price: 0.8032000064849854
# CPE has 5m MFI sell signal with high volume on 20200603-0940, and is under $5. Close price: 0.8104000091552734
# CPE has 5m MFI sell signal with high volume on 20200603-0935, and is under $5. Close price: 0.8123999834060669
# CPE has 5m buy-in signal with high volume on 20200602-1455, and is under $5. Close price: 0.796500027179718
# CPE has 5m MFI sell signal with high volume on 20200602-1450, and is under $5. Close price: 0.7821999788284302
# CPE has 5m buy-in signal with high volume on 20200602-1445, and is under $5. Close price: 0.7839999794960022
# CPE has 5m buy-in signal with high volume on 20200602-1435, and is under $5. Close price: 0.7748000025749207
# CRIS has 5m MFI buy signal with high volume on 20200610-1415, and is under $5. Close price: 2.450000047683716
# CRIS has 5m plateau signal with high volume on 20200610-1405, and is under $5. Close price: 2.630000114440918
# CRIS has 5m MFI buy signal with high volume on 20200610-1405, and is under $5. Close price: 2.630000114440918
# CSU has 5m buy-in signal with high volume on 20200609-0935, and is under $5. Close price: 1.7200000286102295
# CSU has 5m buy-in signal with high volume on 20200608-1535, and is under $5. Close price: 1.4800000190734863
# CULP has 5m buy-in signal with high volume on 20200608-0955, and is under $5. Close price: 8.411999702453612
# CULP has 5m buy-in signal with high volume on 20200608-0945, and is under $5. Close price: 8.473999977111816
# CVE has 5m MFI sell signal with high volume on 20200610-1420, and is under $5. Close price: 5.3400001525878915
# CVE has 5m MFI buy signal with high volume on 20200610-1305, and is under $5. Close price: 5.184999942779541
# CVE has 5m MFI sell signal with high volume on 20200610-1200, and is under $5. Close price: 5.23390007019043
# CVE has 5m MFI sell signal with high volume on 20200610-1155, and is under $5. Close price: 5.231599807739258
# CVE has 5m plateau signal with high volume on 20200610-1025, and is under $5. Close price: 5.069900035858153
# CVE has 5m plateau signal with high volume on 20200610-0955, and is under $5. Close price: 5.143799781799316
# CVE has 5m MFI sell signal with high volume on 20200609-1515, and is under $5. Close price: 5.434999942779541
# CVE has 5m MFI sell signal with high volume on 20200609-1455, and is under $5. Close price: 5.380000114440918
# CVE has 5m plateau signal with high volume on 20200609-1245, and is under $5. Close price: 5.317800045013428
# CVE has 5m MFI sell signal with high volume on 20200609-1110, and is under $5. Close price: 5.434999942779541
# CVE has 5m MFI sell signal with high volume on 20200609-1055, and is under $5. Close price: 5.454999923706055
# CVE has 5m plateau signal with high volume on 20200609-1015, and is under $5. Close price: 5.389999866485597
# CVE has 5m plateau signal with high volume on 20200609-1010, and is under $5. Close price: 5.369999885559082
# CVE has 5m plateau signal with high volume on 20200609-0950, and is under $5. Close price: 5.454999923706055
# CVE has 5m MFI buy signal with high volume on 20200609-0950, and is under $5. Close price: 5.454999923706055
# CVE has 5m plateau signal with high volume on 20200609-0940, and is under $5. Close price: 5.519999980926514
# CVE has 5m MFI buy signal with high volume on 20200609-0940, and is under $5. Close price: 5.519999980926514
# CVE has 5m plateau signal with high volume on 20200609-0935, and is under $5. Close price: 5.46999979019165
# CVE has 5m MFI sell signal with high volume on 20200608-1120, and is under $5. Close price: 5.570000171661377
# CVE has 5m plateau signal with high volume on 20200605-1220, and is under $5. Close price: 5.210000038146973
# CVE has 5m MFI buy signal with high volume on 20200605-1120, and is under $5. Close price: 5.235000133514403
# CVE has 5m MFI buy signal with high volume on 20200605-1105, and is under $5. Close price: 5.25
# CVE has 5m MFI buy signal with high volume on 20200605-1055, and is under $5. Close price: 5.244999885559082
# CVE has 5m MFI sell signal with high volume on 20200605-0955, and is under $5. Close price: 5.221799850463867
# CVE has 5m MFI sell signal with high volume on 20200605-0935, and is under $5. Close price: 5.184999942779541
# CVE has 5m plateau signal with high volume on 20200604-1120, and is under $5. Close price: 4.71999979019165
# CVE has 5m plateau signal with high volume on 20200604-1105, and is under $5. Close price: 4.744999885559082
# CVE has 5m MFI buy signal with high volume on 20200604-0955, and is under $5. Close price: 4.755000114440918
# CVE has 5m plateau signal with high volume on 20200604-0950, and is under $5. Close price: 4.739999771118164
# CVE has 5m MFI buy signal with high volume on 20200604-0950, and is under $5. Close price: 4.739999771118164
# CVE has 5m MFI sell signal with high volume on 20200603-1120, and is under $5. Close price: 4.829999923706055
# CVE has 5m MFI sell signal with high volume on 20200603-1115, and is under $5. Close price: 4.835000038146973
# CVE has 5m MFI buy signal with high volume on 20200603-1040, and is under $5. Close price: 4.824999809265137
# CVE has 5m MFI buy signal with high volume on 20200603-1015, and is under $5. Close price: 4.864999771118164
# CVE has 5m MFI sell signal with high volume on 20200603-0935, and is under $5. Close price: 4.869999885559082
# CVE has 5m MFI sell signal with high volume on 20200602-1530, and is under $5. Close price: 4.724999904632568
# DLTH has 5m buy-in signal with high volume on 20200610-1555, and is under $5. Close price: 8.350000381469728
# DLTH has 5m plateau signal with high volume on 20200610-1020, and is under $5. Close price: 8.320199966430664
# DLTH has 5m plateau signal with high volume on 20200610-1000, and is under $5. Close price: 8.630000114440918
# DLTH has 5m MFI buy signal with high volume on 20200609-1525, and is under $5. Close price: 9.520000457763672
# DLTH has 5m MFI sell signal with high volume on 20200609-1300, and is under $5. Close price: 8.779999732971191
# DLTH has 5m MFI sell signal with high volume on 20200609-1255, and is under $5. Close price: 8.850000381469727
# DLTH has 5m buy-in signal with high volume on 20200609-1250, and is under $5. Close price: 8.920000076293945
# DLTH has 5m buy-in signal with high volume on 20200609-1240, and is under $5. Close price: 8.5
# DLTH has 5m buy-in signal with high volume on 20200609-1235, and is under $5. Close price: 8.079899787902832
# DLTH has 5m plateau signal with high volume on 20200609-1010, and is under $5. Close price: 7.440000057220459
# DLTH has 5m plateau signal with high volume on 20200609-1000, and is under $5. Close price: 7.4099998474121085
# DLTH has 5m MFI buy signal with high volume on 20200608-1025, and is under $5. Close price: 7.544600009918213
# DLTH has 5m MFI sell signal with high volume on 20200608-0950, and is under $5. Close price: 7.640500068664551
# DLTH has 5m buy-in signal with high volume on 20200608-0945, and is under $5. Close price: 7.968400001525879
# DLTH has 5m buy-in signal with high volume on 20200608-0940, and is under $5. Close price: 7.889999866485597
# DLTH has 5m MFI sell signal with high volume on 20200605-0945, and is under $5. Close price: 7.430099964141847
# DLTH has 5m buy-in signal with high volume on 20200605-0940, and is under $5. Close price: 7.460000038146973
# DLTH has 5m MFI sell signal with high volume on 20200605-0935, and is under $5. Close price: 7.324999809265138
# DLTH has 5m buy-in signal with high volume on 20200604-1535, and is under $5. Close price: 6.610000133514403
# DNR has 5m plateau signal with high volume on 20200610-1530, and is under $5. Close price: 0.5333499908447266
# DNR has 5m MFI buy signal with high volume on 20200610-1530, and is under $5. Close price: 0.5333499908447266
# DNR has 5m MFI buy signal with high volume on 20200610-1525, and is under $5. Close price: 0.5189999938011169
# DNR has 5m MFI sell signal with high volume on 20200610-1420, and is under $5. Close price: 0.5849000215530396
# DNR has 5m MFI sell signal with high volume on 20200610-1155, and is under $5. Close price: 0.5333999991416931
# DNR has 5m MFI sell signal with high volume on 20200610-1105, and is under $5. Close price: 0.4909999966621399
# DNR has 5m plateau signal with high volume on 20200610-1025, and is under $5. Close price: 0.4467000067234039
# DNR has 5m plateau signal with high volume on 20200610-1020, and is under $5. Close price: 0.4379000067710877
# DNR has 5m MFI buy signal with high volume on 20200610-1000, and is under $5. Close price: 0.4530499875545502
# DNR has 5m plateau signal with high volume on 20200609-1555, and is under $5. Close price: 0.5791000127792358
# DNR has 5m MFI buy signal with high volume on 20200609-1450, and is under $5. Close price: 0.5871999859809875
# DNR has 5m plateau signal with high volume on 20200609-1255, and is under $5. Close price: 0.578000009059906
# DNR has 5m MFI buy signal with high volume on 20200609-1225, and is under $5. Close price: 0.5820000171661377
# DNR has 5m plateau signal with high volume on 20200609-0935, and is under $5. Close price: 0.6297000050544739
# DNR has 5m buy-in signal with high volume on 20200608-1550, and is under $5. Close price: 0.7264999747276306
# DNR has 5m MFI sell signal with high volume on 20200608-1340, and is under $5. Close price: 0.6912999749183655
# DNR has 5m buy-in signal with high volume on 20200608-1330, and is under $5. Close price: 0.6930000185966492
# DNR has 5m buy-in signal with high volume on 20200608-1325, and is under $5. Close price: 0.6650000214576721
# DNR has 5m MFI sell signal with high volume on 20200608-1005, and is under $5. Close price: 0.6049000024795532
# DNR has 5m MFI sell signal with high volume on 20200608-0955, and is under $5. Close price: 0.5922999978065491
# DNR has 5m MFI sell signal with high volume on 20200608-0950, and is under $5. Close price: 0.6298999786376953
# DNR has 5m MFI sell signal with high volume on 20200608-0945, and is under $5. Close price: 0.6492000222206116
# DNR has 5m buy-in signal with high volume on 20200608-0935, and is under $5. Close price: 0.6025000214576721
# DNR has 5m buy-in signal with high volume on 20200605-1420, and is under $5. Close price: 0.35899999737739563
# DNR has 5m buy-in signal with high volume on 20200605-1150, and is under $5. Close price: 0.33354899287223816
# DNR has 5m buy-in signal with high volume on 20200605-1120, and is under $5. Close price: 0.3050999939441681
# DNR has 5m buy-in signal with high volume on 20200605-0950, and is under $5. Close price: 0.2992999851703644
# DNR has 5m buy-in signal with high volume on 20200605-0945, and is under $5. Close price: 0.2888999879360199
# DNR has 5m buy-in signal with high volume on 20200604-1435, and is under $5. Close price: 0.2502999901771545
# DNR has 5m buy-in signal with high volume on 20200602-1455, and is under $5. Close price: 0.25679999589920044
# DXLG has 5m MFI sell signal with high volume on 20200610-1455, and is under $5. Close price: 0.7041500210762024
# DXLG has 5m buy-in signal with high volume on 20200610-1450, and is under $5. Close price: 0.7300000190734863
# DXLG has 5m MFI sell signal with high volume on 20200609-1150, and is under $5. Close price: 0.7893000245094299
# DXLG has 5m MFI sell signal with high volume on 20200609-1140, and is under $5. Close price: 0.8296999931335449
# DXLG has 5m buy-in signal with high volume on 20200609-1135, and is under $5. Close price: 0.8174999952316284
# DXLG has 5m MFI sell signal with high volume on 20200609-1120, and is under $5. Close price: 0.7200000286102295
# DXLG has 5m buy-in signal with high volume on 20200609-1110, and is under $5. Close price: 0.7350010275840759
# DXLG has 5m buy-in signal with high volume on 20200609-1105, and is under $5. Close price: 0.6899499893188477
# ECOR has 5m buy-in signal with high volume on 20200610-1025, and is under $5. Close price: 1.121999979019165
# ECOR has 5m buy-in signal with high volume on 20200608-1245, and is under $5. Close price: 1.2223999500274658
# ECOR has 5m buy-in signal with high volume on 20200608-1230, and is under $5. Close price: 1.2200000286102295
# EGLE has 5m plateau signal with high volume on 20200609-0950, and is under $5. Close price: 2.809999942779541
# EGLE has 5m plateau signal with high volume on 20200609-0945, and is under $5. Close price: 2.75
# EGLE has 5m buy-in signal with high volume on 20200608-0935, and is under $5. Close price: 2.7100000381469727
# EGLE has 5m buy-in signal with high volume on 20200605-0940, and is under $5. Close price: 2.549999952316284
# ENT has 5m plateau signal with high volume on 20200610-1115, and is under $5. Close price: 7.289199829101562
# ENT has 5m buy-in signal with high volume on 20200609-1055, and is under $5. Close price: 12.31999969482422
# ENT has 5m buy-in signal with high volume on 20200609-1050, and is under $5. Close price: 11.370100021362305
# ENT has 5m buy-in signal with high volume on 20200608-1555, and is under $5. Close price: 9.869999885559082
# ENT has 5m buy-in signal with high volume on 20200608-1545, and is under $5. Close price: 9.675000190734863
# EYPT has 5m buy-in signal with high volume on 20200608-1225, and is under $5. Close price: 0.959999978542328
# EYPT has 5m buy-in signal with high volume on 20200608-1215, and is under $5. Close price: 0.960099995136261
# EYPT has 5m buy-in signal with high volume on 20200608-1210, and is under $5. Close price: 0.9275590181350708
# FET has 5m buy-in signal with high volume on 20200610-1410, and is under $5. Close price: 0.809499979019165
# FET has 5m plateau signal with high volume on 20200610-1005, and is under $5. Close price: 0.5899999737739563
# FET has 5m plateau signal with high volume on 20200610-0935, and is under $5. Close price: 0.669950008392334
# FET has 5m buy-in signal with high volume on 20200609-1505, and is under $5. Close price: 0.8398000001907349
# FET has 5m plateau signal with high volume on 20200609-1355, and is under $5. Close price: 0.8019999861717224
# FET has 5m plateau signal with high volume on 20200609-1025, and is under $5. Close price: 0.8360499739646912
# FET has 5m MFI sell signal with high volume on 20200608-1435, and is under $5. Close price: 0.9800000190734864
# FET has 5m buy-in signal with high volume on 20200608-1400, and is under $5. Close price: 0.9344000220298768
# FET has 5m MFI sell signal with high volume on 20200608-1330, and is under $5. Close price: 0.9135000109672546
# FET has 5m buy-in signal with high volume on 20200608-1325, and is under $5. Close price: 0.912917971611023
# FET has 5m MFI sell signal with high volume on 20200608-1035, and is under $5. Close price: 0.8644999861717224
# FET has 5m MFI sell signal with high volume on 20200608-0935, and is under $5. Close price: 0.7044000029563904
# FET has 5m buy-in signal with high volume on 20200605-1510, and is under $5. Close price: 0.4977000057697296
# FET has 5m buy-in signal with high volume on 20200605-1455, and is under $5. Close price: 0.4950999915599823
# FET has 5m buy-in signal with high volume on 20200605-1450, and is under $5. Close price: 0.4848000109195709
# FET has 5m buy-in signal with high volume on 20200605-1235, and is under $5. Close price: 0.4424999952316284
# FET has 5m buy-in signal with high volume on 20200605-0935, and is under $5. Close price: 0.37700000405311584
# FET has 5m MFI sell signal with high volume on 20200602-1500, and is under $5. Close price: 0.3400000035762787
# FET has 5m buy-in signal with high volume on 20200602-1455, and is under $5. Close price: 0.3438999950885773
# FOSL has 5m MFI buy signal with high volume on 20200610-1525, and is under $5. Close price: 5.110000133514403
# FOSL has 5m MFI sell signal with high volume on 20200610-1430, and is under $5. Close price: 5.320000171661377
# FOSL has 5m buy-in signal with high volume on 20200610-1425, and is under $5. Close price: 5.4099998474121085
# FOSL has 5m plateau signal with high volume on 20200609-1550, and is under $5. Close price: 5.045000076293945
# FOSL has 5m plateau signal with high volume on 20200609-1535, and is under $5. Close price: 5.177000045776367
# FOSL has 5m MFI buy signal with high volume on 20200609-1515, and is under $5. Close price: 5.255000114440918
# FOSL has 5m MFI buy signal with high volume on 20200609-1455, and is under $5. Close price: 5.335000038146973
# FOSL has 5m MFI buy signal with high volume on 20200609-1435, and is under $5. Close price: 5.545000076293945
# FOSL has 5m MFI buy signal with high volume on 20200609-1430, and is under $5. Close price: 5.5
# FOSL has 5m plateau signal with high volume on 20200609-1245, and is under $5. Close price: 5.7845001220703125
# FOSL has 5m plateau signal with high volume on 20200609-1120, and is under $5. Close price: 5.800000190734862
# FOSL has 5m MFI buy signal with high volume on 20200609-1110, and is under $5. Close price: 5.855000019073486
# FOSL has 5m plateau signal with high volume on 20200609-1035, and is under $5. Close price: 6.039999961853027
# FOSL has 5m buy-in signal with high volume on 20200608-1550, and is under $5. Close price: 8.029999732971191
# FOSL has 5m MFI sell signal with high volume on 20200608-1500, and is under $5. Close price: 7.678999900817871
# FOSL has 5m MFI sell signal with high volume on 20200608-1455, and is under $5. Close price: 7.704999923706055
# FOSL has 5m MFI sell signal with high volume on 20200608-1435, and is under $5. Close price: 7.639999866485597
# FOSL has 5m buy-in signal with high volume on 20200608-1425, and is under $5. Close price: 7.552000045776367
# FOSL has 5m MFI sell signal with high volume on 20200608-1220, and is under $5. Close price: 7.4650001525878915
# FOSL has 5m buy-in signal with high volume on 20200608-1215, and is under $5. Close price: 7.513700008392334
# FOSL has 5m buy-in signal with high volume on 20200608-1155, and is under $5. Close price: 7.096499919891357
# FOSL has 5m buy-in signal with high volume on 20200608-0950, and is under $5. Close price: 5.744999885559082
# FOSL has 5m buy-in signal with high volume on 20200608-0940, and is under $5. Close price: 5.75
# FOSL has 5m buy-in signal with high volume on 20200605-1420, and is under $5. Close price: 5.320000171661377
# FOSL has 5m buy-in signal with high volume on 20200605-0935, and is under $5. Close price: 4.769899845123291
# FOSL has 5m buy-in signal with high volume on 20200604-1315, and is under $5. Close price: 4.565000057220459
# FOSL has 5m MFI sell signal with high volume on 20200604-1005, and is under $5. Close price: 4.1672000885009775
# FOSL has 5m buy-in signal with high volume on 20200604-1000, and is under $5. Close price: 4.183800220489502
# FOSL has 5m MFI sell signal with high volume on 20200604-0955, and is under $5. Close price: 4.019999980926514
# FOSL has 5m plateau signal with high volume on 20200603-1545, and is under $5. Close price: 3.7799999713897705
# FOSL has 5m buy-in signal with high volume on 20200603-1355, and is under $5. Close price: 3.833899974822998
# FSK has 5m plateau signal with high volume on 20200610-1030, and is under $5. Close price: 4.139999866485597
# FSK has 5m plateau signal with high volume on 20200610-1025, and is under $5. Close price: 4.0900001525878915
# FSK has 5m plateau signal with high volume on 20200610-1015, and is under $5. Close price: 4.125
# FSK has 5m plateau signal with high volume on 20200610-0955, and is under $5. Close price: 4.190000057220459
# FSK has 5m MFI buy signal with high volume on 20200609-1535, and is under $5. Close price: 4.4099998474121085
# FSK has 5m MFI buy signal with high volume on 20200609-1240, and is under $5. Close price: 4.400000095367432
# FSK has 5m plateau signal with high volume on 20200609-1230, and is under $5. Close price: 4.425000190734863
# ...
# VAL has 5m MFI sell signal with high volume on 20200605-0935, and is under $5. Close price: 0.3977000117301941
# VAL has 5m buy-in signal with high volume on 20200603-1550, and is under $5. Close price: 0.35100001096725464
# VAL has 5m buy-in signal with high volume on 20200602-1500, and is under $5. Close price: 0.33000001311302185
# WLL has 5m plateau signal with high volume on 20200610-1555, and is under $5. Close price: 1.5750000476837158
# WLL has 5m MFI buy signal with high volume on 20200610-1555, and is under $5. Close price: 1.5750000476837158
# WLL has 5m MFI buy signal with high volume on 20200610-1505, and is under $5. Close price: 1.7599999904632568
# WLL has 5m MFI buy signal with high volume on 20200610-1355, and is under $5. Close price: 1.7685999870300293
# WLL has 5m MFI buy signal with high volume on 20200610-1305, and is under $5. Close price: 1.830000042915344
# WLL has 5m MFI buy signal with high volume on 20200610-1240, and is under $5. Close price: 1.8086999654769895
# WLL has 5m buy-in signal with high volume on 20200610-1150, and is under $5. Close price: 1.989199995994568
# WLL has 5m MFI sell signal with high volume on 20200610-1110, and is under $5. Close price: 1.8400000333786009
# WLL has 5m plateau signal with high volume on 20200610-1025, and is under $5. Close price: 1.6599999666213991
# WLL has 5m MFI buy signal with high volume on 20200610-1015, and is under $5. Close price: 1.6402000188827517
# WLL has 5m MFI buy signal with high volume on 20200610-1000, and is under $5. Close price: 1.6699999570846558
# WLL has 5m plateau signal with high volume on 20200610-0935, and is under $5. Close price: 1.8899999856948853
# WLL has 5m MFI buy signal with high volume on 20200609-1505, and is under $5. Close price: 2.365499973297119
# WLL has 5m MFI buy signal with high volume on 20200609-1450, and is under $5. Close price: 2.4300000667572017
# WLL has 5m MFI buy signal with high volume on 20200609-1445, and is under $5. Close price: 2.3798999786376958
# WLL has 5m MFI buy signal with high volume on 20200609-1255, and is under $5. Close price: 2.565000057220459
# WLL has 5m MFI sell signal with high volume on 20200609-1050, and is under $5. Close price: 2.48009991645813
# WLL has 5m buy-in signal with high volume on 20200608-1555, and is under $5. Close price: 3.5
# WLL has 5m MFI sell signal with high volume on 20200608-1505, and is under $5. Close price: 3.0699999332427983
# WLL has 5m buy-in signal with high volume on 20200608-1325, and is under $5. Close price: 2.9298999309539795
# WLL has 5m buy-in signal with high volume on 20200608-1305, and is under $5. Close price: 2.6600000858306885
# WLL has 5m MFI sell signal with high volume on 20200608-1005, and is under $5. Close price: 2.2100999355316158
# WLL has 5m MFI sell signal with high volume on 20200608-0955, and is under $5. Close price: 2.1584000587463383
# WLL has 5m MFI sell signal with high volume on 20200608-0950, and is under $5. Close price: 2.184999942779541
# WLL has 5m buy-in signal with high volume on 20200608-0940, and is under $5. Close price: 2.2400999069213867
# WLL has 5m buy-in signal with high volume on 20200608-0935, and is under $5. Close price: 2.1191000938415527
# WLL has 5m buy-in signal with high volume on 20200605-1555, and is under $5. Close price: 1.3799999952316284
# WLL has 5m buy-in signal with high volume on 20200605-1430, and is under $5. Close price: 1.294100046157837
# WLL has 5m MFI sell signal with high volume on 20200605-1005, and is under $5. Close price: 1.1710000038146973
# WLL has 5m buy-in signal with high volume on 20200605-1000, and is under $5. Close price: 1.24399995803833
# WLL has 5m buy-in signal with high volume on 20200605-0950, and is under $5. Close price: 1.1299999952316284
# WLL has 5m buy-in signal with high volume on 20200605-0945, and is under $5. Close price: 1.0721000432968142
# WLL has 5m buy-in signal with high volume on 20200605-0940, and is under $5. Close price: 1.0399999618530271
# WLL has 5m buy-in signal with high volume on 20200605-0935, and is under $5. Close price: 1.01010000705719
# WLL has 5m plateau signal with high volume on 20200604-1005, and is under $5. Close price: 0.8399999737739563
# WLL has 5m buy-in signal with high volume on 20200603-1135, and is under $5. Close price: 0.8883000016212463
# WPG has 5m plateau signal with high volume on 20200610-1350, and is under $5. Close price: 1.207800030708313
# WPG has 5m plateau signal with high volume on 20200610-1035, and is under $5. Close price: 1.180500030517578
# WPG has 5m plateau signal with high volume on 20200610-1000, and is under $5. Close price: 1.2100000381469729
# WPG has 5m plateau signal with high volume on 20200610-0955, and is under $5. Close price: 1.184999942779541
# WPG has 5m MFI buy signal with high volume on 20200610-0955, and is under $5. Close price: 1.184999942779541
# WPG has 5m plateau signal with high volume on 20200610-0945, and is under $5. Close price: 1.1821999549865725
# WPG has 5m MFI buy signal with high volume on 20200610-0945, and is under $5. Close price: 1.1821999549865725
# WPG has 5m buy-in signal with high volume on 20200609-1540, and is under $5. Close price: 1.4249999523162842
# WPG has 5m plateau signal with high volume on 20200609-1300, and is under $5. Close price: 1.3899999856948853
# WPG has 5m MFI sell signal with high volume on 20200609-1125, and is under $5. Close price: 1.4850000143051147
# WPG has 5m plateau signal with high volume on 20200609-1020, and is under $5. Close price: 1.399999976158142
# WPG has 5m plateau signal with high volume on 20200609-1015, and is under $5. Close price: 1.3467999696731567
# WPG has 5m MFI sell signal with high volume on 20200608-1540, and is under $5. Close price: 1.6649999618530271
# WPG has 5m MFI buy signal with high volume on 20200608-1430, and is under $5. Close price: 1.628000020980835
# WPG has 5m plateau signal with high volume on 20200608-1425, and is under $5. Close price: 1.629899978637695
# WPG has 5m MFI sell signal with high volume on 20200608-1130, and is under $5. Close price: 1.7799999713897705
# WPG has 5m buy-in signal with high volume on 20200608-0935, and is under $5. Close price: 1.5900000333786009
# WPG has 5m MFI sell signal with high volume on 20200605-1440, and is under $5. Close price: 1.160099983215332
# WPG has 5m MFI sell signal with high volume on 20200605-1415, and is under $5. Close price: 1.100000023841858
# WPG has 5m buy-in signal with high volume on 20200605-1410, and is under $5. Close price: 1.1100000143051147
# WPG has 5m buy-in signal with high volume on 20200605-1405, and is under $5. Close price: 1.0839999914169312
# WPG has 5m MFI sell signal with high volume on 20200605-1155, and is under $5. Close price: 1.012997031211853
# WPG has 5m MFI sell signal with high volume on 20200605-1120, and is under $5. Close price: 0.9882000088691713
# WPG has 5m buy-in signal with high volume on 20200605-1000, and is under $5. Close price: 0.9672499895095824
# WPG has 5m buy-in signal with high volume on 20200605-0950, and is under $5. Close price: 0.9997000098228456
# WPG has 5m buy-in signal with high volume on 20200604-1450, and is under $5. Close price: 0.8220000267028809
# WPG has 5m MFI sell signal with high volume on 20200604-1215, and is under $5. Close price: 0.7788000106811523
# WPG has 5m buy-in signal with high volume on 20200604-1205, and is under $5. Close price: 0.7698000073432922
# WPG has 5m buy-in signal with high volume on 20200604-1155, and is under $5. Close price: 0.7584549784660339
# WPG has 5m plateau signal with high volume on 20200602-1545, and is under $5. Close price: 0.6647999882698059
# XBIO has 5m MFI sell signal with high volume on 20200610-1555, and is under $5. Close price: 1.309999942779541
# XBIO has 5m buy-in signal with high volume on 20200610-1545, and is under $5. Close price: 1.3078999519348145
# XBIO has 5m buy-in signal with high volume on 20200610-1540, and is under $5. Close price: 1.2400000095367432
# XELB has 5m buy-in signal with high volume on 20200610-1400, and is under $5. Close price: 1.3799999952316284
# XOG has 5m plateau signal with high volume on 20200610-1015, and is under $5. Close price: 0.6909000277519226
# XOG has 5m MFI buy signal with high volume on 20200610-0945, and is under $5. Close price: 0.714900016784668
# XOG has 5m buy-in signal with high volume on 20200608-1550, and is under $5. Close price: 1.5298999547958374
# XOG has 5m buy-in signal with high volume on 20200608-1540, and is under $5. Close price: 1.5999000072479248
# XOG has 5m buy-in signal with high volume on 20200608-1535, and is under $5. Close price: 1.350000023841858
# XOG has 5m buy-in signal with high volume on 20200608-1525, and is under $5. Close price: 1.2799999713897705
# XOG has 5m MFI buy signal with high volume on 20200608-1435, and is under $5. Close price: 1.097000002861023
# XOG has 5m MFI sell signal with high volume on 20200608-1405, and is under $5. Close price: 1.0900000333786009
# XOG has 5m MFI sell signal with high volume on 20200608-1400, and is under $5. Close price: 1.100000023841858
# XOG has 5m MFI sell signal with high volume on 20200608-1340, and is under $5. Close price: 1.0753999948501587
# XOG has 5m buy-in signal with high volume on 20200608-1335, and is under $5. Close price: 1.0900000333786009
# XOG has 5m MFI sell signal with high volume on 20200608-1025, and is under $5. Close price: 1.0499000549316406
# XOG has 5m MFI sell signal with high volume on 20200608-1015, and is under $5. Close price: 1.0475000143051147
# XOG has 5m MFI sell signal with high volume on 20200608-1010, and is under $5. Close price: 1.0679999589920044
# XOG has 5m MFI sell signal with high volume on 20200608-0950, and is under $5. Close price: 1.0800000429153442
# XOG has 5m MFI sell signal with high volume on 20200608-0940, and is under $5. Close price: 0.9499999880790709
# XOG has 5m buy-in signal with high volume on 20200608-0935, and is under $5. Close price: 0.959999978542328
# XOG has 5m buy-in signal with high volume on 20200605-1435, and is under $5. Close price: 0.4129999876022339
# XOG has 5m MFI sell signal with high volume on 20200605-1205, and is under $5. Close price: 0.3804000020027161
# XOG has 5m buy-in signal with high volume on 20200605-1200, and is under $5. Close price: 0.3822000026702881
# XOG has 5m buy-in signal with high volume on 20200605-1125, and is under $5. Close price: 0.34255000948905945
# XOG has 5m buy-in signal with high volume on 20200605-1005, and is under $5. Close price: 0.3244999945163727
# XXII has 5m buy-in signal with high volume on 20200609-1545, and is under $5. Close price: 0.989400029182434
# XXII has 5m buy-in signal with high volume on 20200608-1145, and is under $5. Close price: 1.0099999904632568
# XXII has 5m MFI sell signal with high volume on 20200608-1040, and is under $5. Close price: 0.9251999855041504
# XXII has 5m buy-in signal with high volume on 20200608-0935, and is under $5. Close price: 0.8289999961853027
# XXII has 5m buy-in signal with high volume on 20200605-1040, and is under $5. Close price: 0.8208000063896179
# ZAGG has 5m buy-in signal with high volume on 20200610-1240, and is under $5. Close price: 3.8199000358581534
# ZAGG has 5m buy-in signal with high volume on 20200610-1235, and is under $5. Close price: 3.768199920654297
# ZAGG has 5m buy-in signal with high volume on 20200608-1550, and is under $5. Close price: 4.550000190734863
# ZAGG has 5m buy-in signal with high volume on 20200608-1545, and is under $5. Close price: 4.418099880218506
# ZAGG has 5m MFI sell signal with high volume on 20200608-1400, and is under $5. Close price: 4.270699977874757
# ZAGG has 5m buy-in signal with high volume on 20200608-1225, and is under $5. Close price: 4.010000228881837
# ZAGG has 5m buy-in signal with high volume on 20200608-1130, and is under $5. Close price: 3.7899999618530273
# ZAGG has 5m buy-in signal with high volume on 20200608-1125, and is under $5. Close price: 3.734999895095825
# ZAGG has 5m buy-in signal with high volume on 20200608-1005, and is under $5. Close price: 3.5199999809265137
# ZAGG has 5m buy-in signal with high volume on 20200608-0935, and is under $5. Close price: 3.414999961853028
# ZAGG has 5m buy-in signal with high volume on 20200605-1045, and is under $5. Close price: 3.184999942779541
# ZAGG has 5m buy-in signal with high volume on 20200605-0940, and is under $5. Close price: 3.0999999046325684
# ^DJI has 5m plateau signal with high volume on 20200610-1455, and is under $5. Close price: 27090.25
# ^DJI has 5m MFI sell signal with high volume on 20200610-1405, and is under $5. Close price: 27255.259765625
# ^DJI has 5m plateau signal with high volume on 20200610-1030, and is under $5. Close price: 27040.419921875
# ^DJI has 5m plateau signal with high volume on 20200610-1025, and is under $5. Close price: 27005.109375
# ^DJI has 5m MFI buy signal with high volume on 20200610-1020, and is under $5. Close price: 26972.69921875
# ^DJI has 5m plateau signal with high volume on 20200610-1005, and is under $5. Close price: 27128.9296875
# ^DJI has 5m MFI buy signal with high volume on 20200610-1005, and is under $5. Close price: 27128.9296875
# ^DJI has 5m plateau signal with high volume on 20200610-0955, and is under $5. Close price: 27125.099609375
# ^DJI has 5m MFI sell signal with high volume on 20200609-1300, and is under $5. Close price: 27374.80078125
# ^DJI has 5m MFI sell signal with high volume on 20200609-1240, and is under $5. Close price: 27343.23046875
# ^DJI has 5m MFI buy signal with high volume on 20200609-1150, and is under $5. Close price: 27294.609375
# ^DJI has 5m MFI buy signal with high volume on 20200609-1140, and is under $5. Close price: 27316.650390625
# ^DJI has 5m plateau signal with high volume on 20200609-0940, and is under $5. Close price: 27293.390625
# ^DJI has 5m MFI sell signal with high volume on 20200608-1000, and is under $5. Close price: 27359.7109375
# ^DJI has 5m MFI sell signal with high volume on 20200608-0945, and is under $5. Close price: 27364.69921875
# ^DJI has 5m MFI buy signal with high volume on 20200605-1415, and is under $5. Close price: 27158.8203125
# ^DJI has 5m MFI sell signal with high volume on 20200605-1135, and is under $5. Close price: 27244.080078125
# ^DJI has 5m MFI sell signal with high volume on 20200605-1115, and is under $5. Close price: 27185.19921875
# ^DJI has 5m MFI sell signal with high volume on 20200605-1105, and is under $5. Close price: 27141.44921875
# ^DJI has 5m MFI sell signal with high volume on 20200605-0945, and is under $5. Close price: 27043.759765625
# ^DJI has 5m plateau signal with high volume on 20200604-1515, and is under $5. Close price: 26136.310546875
# ^DJI has 5m plateau signal with high volume on 20200604-1250, and is under $5. Close price: 26177.44921875
# ^DJI has 5m plateau signal with high volume on 20200604-1235, and is under $5. Close price: 26193.509765625
# ^DJI has 5m MFI sell signal with high volume on 20200603-1550, and is under $5. Close price: 26312.94921875
# ^DJI has 5m MFI sell signal with high volume on 20200603-1545, and is under $5. Close price: 26317.3203125
# ^DJI has 5m MFI sell signal with high volume on 20200603-1325, and is under $5. Close price: 26151.330078125
# ^DJI has 5m MFI sell signal with high volume on 20200603-1050, and is under $5. Close price: 26070.91015625
# ^DJI has 5m MFI sell signal with high volume on 20200603-1045, and is under $5. Close price: 26073.830078125
# ^DJI has 5m MFI sell signal with high volume on 20200603-0945, and is under $5. Close price: 25975.25
# ^DJI has 5m MFI sell signal with high volume on 20200603-0935, and is under $5. Close price: 25942.509765625
# ^DJI has 5m plateau signal with high volume on 20200602-1445, and is under $5. Close price: 25620.8203125
# ^DJI has 5m plateau signal with high volume on 20200602-1440, and is under $5. Close price: 25604.060546875
# ^DJI has 5m plateau signal with high volume on 20200602-1435, and is under $5. Close price: 25579.4609375

# %%
#email output
with open('C:\\Users\\Richard\\Desktop\\Python\\hotmail.txt', 'rb') as f:
    email_list = str(f.read()).split(',')
    emailAddress = email_list[0][2:]
    password = email_list[1][:-1]

    msg = MIMEText(to_send)
    recipients = [emailAddress, 'michelleusdenski@gmail.com','guowei88888@msn.com']#'jacob.si@outlook.com','Greggh_101@hotmail.com']
    msg['Subject'] = '%s stock analysis - Intraday Buy-ins: potentials - %s' % (str(datetime.datetime.today().strftime('%Y%m%d-%H%M')), str(len(to_send.split('\n'))-1))
    msg['From'] = emailAddress
    msg['To'] = ', '.join(recipients)
    try:
        s = smtplib.SMTP('smtp-mail.outlook.com', 25)
        s.ehlo()  # Hostname to send for this command defaults to the fully qualified domain name of the local host.
        s.starttls()  # Puts connection to SMTP server in TLS mode
        s.ehlo()
        s.login(emailAddress, password)
        s.sendmail(emailAddress, recipients, msg.as_string())
        s.quit()
        print ('email sent to: %s' % emailAddress)
    except:
        raise
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-e656d4bc77cf> in <module>
#      15         s.starttls()  # Puts connection to SMTP server in TLS mode
#      16         s.ehlo()
# ---> 17         s.login(emailAddress, password)
#      18         s.sendmail(emailAddress, recipients, msg.as_string())
#      19         s.quit()
#
# ~\Anaconda3\lib\smtplib.py in login(self, user, password, initial_response_ok)
#     719                 (code, resp) = self.auth(
#     720                     authmethod, getattr(self, method_name),
# --> 721                     initial_response_ok=initial_response_ok)
#     722                 # 235 == 'Authentication successful'
#     723                 # 503 == 'Error: already authenticated'
#
# ~\Anaconda3\lib\smtplib.py in auth(self, mechanism, authobject, initial_response_ok)
#     637             response = encode_base64(
#     638                 authobject(challenge).encode('ascii'), eol='')
# --> 639             (code, resp) = self.docmd(response)
#     640         if code in (235, 503):
#     641             return (code, resp)
#
# ~\Anaconda3\lib\smtplib.py in docmd(self, cmd, args)
#     419         """Send a command, and return its response code."""
#     420         self.putcmd(cmd, args)
# --> 421         return self.getreply()
#     422
#     423     # std smtp commands
#
# ~\Anaconda3\lib\smtplib.py in getreply(self)
#     385         while 1:
#     386             try:
# --> 387                 line = self.file.readline(_MAXLINE + 1)
#     388             except OSError as e:
#     389                 self.close()
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1050                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1051                   self.__class__)
# -> 1052             return self.read(nbytes, buffer)
#    1053         else:
#    1054             return super().recv_into(buffer, nbytes, flags)
#
# ~\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     909         try:
#     910             if buffer is not None:
# --> 911                 return self._sslobj.read(len, buffer)
#     912             else:
#     913                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
'''
Backlog: 
-Incorporate MACD indicators
-scrape float and add to logic
-Test intraday buyin candlestick signals
'''
