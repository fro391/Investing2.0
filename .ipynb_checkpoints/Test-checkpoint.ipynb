# %%
import datetime
import time
import requests

import json
import os
import pandas as pd
import numpy as np

#threading
import threading
import timeit

from email.mime.text import MIMEText
import smtplib

import gc
import sys

#declare global lock object
global lock
lock = threading.Lock()

# %%
def symbol_downloader(symbol, directory, days=600, days_ago=0):
    dt = datetime.datetime.now()
    UnixTime = int(time.mktime(dt.timetuple()))
    #web variables
    url = 'https://query1.finance.yahoo.com/v8/finance/chart/'+symbol+'?period1='+str(UnixTime-86400*(days+days_ago))+'&period2='+str(UnixTime-86400*days_ago)+'&interval=1d&indicators=quote%7Csma~60&includePrePost=true&events=div%7Csplit%7Cearn&lang=en-CA&region=CA&corsDomain=ca.finance.yahoo.com'
    #proxies
    http_proxy  = ''
    https_proxy = ''
    ftp_proxy   = ''
    proxyDict = { 
                  "http"  : http_proxy, 
                  "https" : https_proxy, 
                  "ftp"   : ftp_proxy
                }

    hdr = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.101 Safari/537.36',
       'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
       'Connection': 'keep-alive'}
    
    try:
        resp = requests.get(url, headers=hdr)
        if resp.status_code != 200:
            # This means something went wrong.
            print(resp.status_code)
        data = json.loads(resp.text)
        #json unpack
        timestamp = data['chart']['result'][0]['timestamp']
        timestamp = [datetime.datetime.fromtimestamp(x).strftime('%Y%m%d') for x in timestamp]
        quote = data['chart']['result'][0]['indicators']['quote'][0]
        sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
        stock_df = pd.DataFrame(quote)
        #index is symbol and timestamp
        stock_df.index = [str(x) for x in timestamp]

        #moving averages
        stock_df['sma60'] = sma60
        stock_df['vol20'] = stock_df['volume'].rolling(window=20).mean()
        stock_df['sma5'] = stock_df['close'].rolling(window=5).mean()
        stock_df['sma8'] = stock_df['close'].rolling(window=8).mean()
        stock_df['sma13'] = stock_df['close'].rolling(window=13).mean()
        stock_df['sma21'] = stock_df['close'].rolling(window=21).mean()
        stock_df['sma34'] = stock_df['close'].rolling(window=34).mean()
        stock_df['sma55'] = stock_df['close'].rolling(window=55).mean()
        stock_df['sma89'] = stock_df['close'].rolling(window=89).mean()
        stock_df['sma144'] = stock_df['close'].rolling(window=144).mean()
        stock_df['sma233'] = stock_df['close'].rolling(window=233).mean()
        stock_df = stock_df.dropna()

        #stock_df.drop(['close', 'high', 'low', 'open','volume','sma','vol20'], axis=1, inplace=True)
        stock_df = stock_df.dropna()
        stock_df = stock_df[~(stock_df == np.inf).any(axis=1)]
        if len(stock_df) != 0:
            stock_df.to_csv('{}{}.csv'.format(directory,symbol[:4]))
        try:
            lock.acquire()
            #clear memory
            gc.collect()
        finally:
            lock.release()
        
    except requests.exceptions.RequestException as e:  # This is the correct syntax
        raise SystemExit(e)

# %%
if __name__ == '__main__':

    #start timer
    start = timeit.default_timer()

    symbolslist = open('symbols.txt').read().split('\n')

    directory = './data_nasdaq/'

    threadlist = []

    for u in symbolslist:

        t = threading.Thread(target = symbol_downloader,args=(u,directory))
        t.start()
        threadlist.append(t)
        #sets top limit of active threads to 20
        while threading.activeCount()>20:
            a=0
        #print threading.activeCount()

    for b in threadlist:
        b.join()
    print ("# of threads: ", len(threadlist))
# Out:
# Exception in thread Thread-19:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-44:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-52:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-82:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-83:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-91:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-92:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-120:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-139:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-169:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-186:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-188:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-225:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-309:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-308:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-371:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-432:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-515:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-669:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-670:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-829:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-967:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-974:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-1005:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-1057:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-1060:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-1085:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-1132:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-1189:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-1194:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-1193:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-1444:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
# 404
# Exception in thread Thread-1608:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-2246:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2344:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
# 404
# Exception in thread Thread-2356:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-2357:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2428:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2478:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2516:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2517:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2518:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2519:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
# 404
# Exception in thread Thread-2566:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-2573:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2574:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2575:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2586:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-2591:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-2596:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2625:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2627:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2641:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2668:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2706:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2728:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2754:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2782:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2785:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2788:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
# 404
# Exception in thread Thread-2794:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-2795:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2804:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
# Exception in thread Thread-2805:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
#
# Exception in thread Thread-2813:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2841:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2849:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2857:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2870:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2886:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2896:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2917:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2958:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2967:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2982:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2984:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2990:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-2999:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3001:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3003:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3024:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3030:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3061:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3073:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3185:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3190:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3197:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3215:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3216:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3217:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3218:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3233:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3248:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3283:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3297:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3299:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3302:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3303:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3305:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3340:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3344:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3359:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3396:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3400:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3401:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3412:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3413:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3425:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 30, in symbol_downloader
#     sma60 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-3465:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
# ...
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# 404
# 404
# 404
# Exception in thread Thread-19162:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# Exception in thread Thread-19159:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
#
# Exception in thread Thread-19164:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-19163:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# 404
# 404
# Exception in thread Thread-19167:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-19166:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-19171:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-19170:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-19168:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-19169:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-19176:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-19177:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-19179:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-19185:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-19186:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-19189:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-19187:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# 404
# 404
# Exception in thread Thread-19194:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-19196:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-19200:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# 404
# Exception in thread Thread-19202:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# Exception in thread Thread-19206:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-19204:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-19213:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-19215:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-19217:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-19220:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-19222:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-19228:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# Exception in thread Thread-19226:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-19229:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-19231:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-19235:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-19237:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4656178b76a0>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# # of threads:  19235

# %%
#Uncle's pattern
import traceback
gc.collect()
to_send = ''
to_save = '^DJI\n'
directory = './data_nasdaq/'
# get list with filenames in folder and throw away all non ncsv
files = [f for f in os.listdir(directory) if f.endswith('.csv')]
for f in files:
    try:
        ticker_df = pd.read_csv(os.path.join(directory, f))
        jones_df = pd.read_csv(os.path.join(directory,'^DJI.csv'))
        
        stock_df = pd.merge(ticker_df, jones_df, left_index=True, right_index=True)

        for i in range(int((len(stock_df)*0.1))): #engulfing candel pattern looping through all available data 
            
            window = 59 #number of days back from today to look at for slope
            
            i += 1 #start range from 1 instead of 0
            
            openTday =  float(stock_df['open_x'].iloc[-i])
            closeTday =  float(stock_df['close_x'].iloc[-i])
            openYday = float(stock_df['open_x'].iloc[-(i+1)])
            closeYday = float(stock_df['close_x'].iloc[-(i+1)])
            
            sma5 = float(stock_df['sma5_x'].iloc[-i])
            sma8 = float(stock_df['sma8_x'].iloc[-i])
            sma13 = float(stock_df['sma13_x'].iloc[-i])
            sma21 = float(stock_df['sma21_x'].iloc[-i])
            
            sma34 = float(stock_df['sma34_x'].iloc[-i])
            
            sma55 = float(stock_df['sma55_x'].iloc[-i])
            sma89 = float(stock_df['sma89_x'].iloc[-i])
            sma144 = float(stock_df['sma144_x'].iloc[-i])
            
            sma233 = float(stock_df['sma233_x'].iloc[-i])
            
            mktVlcty = float(stock_df['volume_x'].iloc[-i])*float(stock_df['close_x'].iloc[-i])
            
            volume = (float(stock_df['volume_x'].iloc[-i])+0.001)/(float(stock_df['vol20_x'].iloc[-i])+0.001)
            
            j_open0 =  float(stock_df['open_y'].iloc[-i])
            j_close0 =  float(stock_df['close_y'].iloc[-i])
            
            stockPChange = (closeTday-openTday)/openTday 
            jonesPChange = (j_close0-j_open0)/j_open0

            #core logic
            if  stockPChange > abs(jonesPChange)*5\
                and openTday < closeTday \
                and sma5<closeTday \
                and sma5 > sma8 and sma8 > sma13 \
                and sma89 < sma5 and sma55 < sma5 \
                and closeTday > sma89 \
                and sma34 < sma144 and sma55 < sma144 and sma89<sma144\
                and sma144 < sma233\
                and closeTday <= 10 and closeTday >= 0.5 \
                and mktVlcty > 1000000\
                and volume >= 2:
                
                to_save += '{}\n'.format(f[:-4])
                to_send += '{} has uncle"s pattern with high volume on {}, and is under $10 \n'.format(f[:-4],(stock_df['Unnamed: 0_x'].iloc[-i]))
                print ('{} has uncle"s pattern with high volume on {}, and is under $10 \n'.format(f[:-4],(stock_df['Unnamed: 0_x'].iloc[-i])))
            #break #only analyze latest date
    except IndexError:
        print("{} has too few rows".format(f))
        pass
    except Exception:
        print(f,stock_df['Unnamed: 0_x'].iloc[-i])
        print(traceback.format_exc())
        # or
        print(sys.exc_info()[2])
        pass
# Out:
# ABEO has uncle"s pattern with high volume on 20200511, and is under $10
#
# AFMD has uncle"s pattern with high volume on 20200519, and is under $10
#
# ANY has uncle"s pattern with high volume on 20200505, and is under $10
#
# ASM has uncle"s pattern with high volume on 20200521, and is under $10
#
# ASM has uncle"s pattern with high volume on 20200519, and is under $10
#
# AUG has uncle"s pattern with high volume on 20200522, and is under $10
#
# AXIM has uncle"s pattern with high volume on 20200526, and is under $10
#
# AXU has uncle"s pattern with high volume on 20200515, and is under $10
#
# CANF has uncle"s pattern with high volume on 20200522, and is under $10
#
# CANF has uncle"s pattern with high volume on 20200521, and is under $10
#
# CASI has uncle"s pattern with high volume on 20200521, and is under $10
#
# CBAY has uncle"s pattern with high volume on 20200511, and is under $10
#
# CCHW has uncle"s pattern with high volume on 20200528, and is under $10
#
# CFMS has uncle"s pattern with high volume on 20200511, and is under $10
#
# CIDM has uncle"s pattern with high volume on 20200520, and is under $10
#
# CKHU.csv 20200505
# Traceback (most recent call last):
#   File "<ipython-input-14-b2e26f3175a2>", line 11, in <module>
#     ticker_df = pd.read_csv(os.path.join(directory, f))
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 702, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 435, in _read
#     data = parser.read(nrows)
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 1139, in read
#     ret = self._engine.read(nrows)
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 1995, in read
#     data = self._reader.read(nrows)
#   File "pandas/_libs/parsers.pyx", line 899, in pandas._libs.parsers.TextReader.read
#   File "pandas/_libs/parsers.pyx", line 914, in pandas._libs.parsers.TextReader._read_low_memory
#   File "pandas/_libs/parsers.pyx", line 968, in pandas._libs.parsers.TextReader._read_rows
#   File "pandas/_libs/parsers.pyx", line 955, in pandas._libs.parsers.TextReader._tokenize_rows
#   File "pandas/_libs/parsers.pyx", line 2172, in pandas._libs.parsers.raise_parser_error
# pandas.errors.ParserError: Error tokenizing data. C error: Expected 17 fields in line 97, saw 18
#
#
# <traceback object at 0x0000028E5C840B08>
# CLSN has uncle"s pattern with high volume on 20200522, and is under $10
#
# CLSN has uncle"s pattern with high volume on 20200521, and is under $10
#
# CLSN has uncle"s pattern with high volume on 20200520, and is under $10
#
# CMT has uncle"s pattern with high volume on 20200511, and is under $10
#
# CNET has uncle"s pattern with high volume on 20200527, and is under $10
#
# CODA.csv 20200505
# Traceback (most recent call last):
#   File "<ipython-input-14-b2e26f3175a2>", line 11, in <module>
#     ticker_df = pd.read_csv(os.path.join(directory, f))
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 702, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 435, in _read
#     data = parser.read(nrows)
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 1139, in read
#     ret = self._engine.read(nrows)
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 1995, in read
#     data = self._reader.read(nrows)
#   File "pandas/_libs/parsers.pyx", line 899, in pandas._libs.parsers.TextReader.read
#   File "pandas/_libs/parsers.pyx", line 914, in pandas._libs.parsers.TextReader._read_low_memory
#   File "pandas/_libs/parsers.pyx", line 968, in pandas._libs.parsers.TextReader._read_rows
#   File "pandas/_libs/parsers.pyx", line 955, in pandas._libs.parsers.TextReader._tokenize_rows
#   File "pandas/_libs/parsers.pyx", line 2172, in pandas._libs.parsers.raise_parser_error
# pandas.errors.ParserError: Error tokenizing data. C error: Expected 17 fields in line 50, saw 25
#
#
# <traceback object at 0x0000028E5C88C7C8>
# COLD.csv 20200505
# Traceback (most recent call last):
#   File "<ipython-input-14-b2e26f3175a2>", line 11, in <module>
#     ticker_df = pd.read_csv(os.path.join(directory, f))
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 702, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 435, in _read
#     data = parser.read(nrows)
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 1139, in read
#     ret = self._engine.read(nrows)
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 1995, in read
#     data = self._reader.read(nrows)
#   File "pandas/_libs/parsers.pyx", line 899, in pandas._libs.parsers.TextReader.read
#   File "pandas/_libs/parsers.pyx", line 914, in pandas._libs.parsers.TextReader._read_low_memory
#   File "pandas/_libs/parsers.pyx", line 968, in pandas._libs.parsers.TextReader._read_rows
#   File "pandas/_libs/parsers.pyx", line 955, in pandas._libs.parsers.TextReader._tokenize_rows
#   File "pandas/_libs/parsers.pyx", line 2172, in pandas._libs.parsers.raise_parser_error
# pandas.errors.ParserError: Error tokenizing data. C error: Expected 17 fields in line 32, saw 18
#
#
# <traceback object at 0x0000028E5C8651C8>
# CPST has uncle"s pattern with high volume on 20200511, and is under $10
#
# CURL has uncle"s pattern with high volume on 20200518, and is under $10
#
# CVSI has uncle"s pattern with high volume on 20200526, and is under $10
#
# CVSI has uncle"s pattern with high volume on 20200522, and is under $10
#
# DCAR has uncle"s pattern with high volume on 20200521, and is under $10
#
# DCAR has uncle"s pattern with high volume on 20200515, and is under $10
#
# DFIN has uncle"s pattern with high volume on 20200529, and is under $10
#
# EDUC has uncle"s pattern with high volume on 20200528, and is under $10
#
# ENOB has uncle"s pattern with high volume on 20200513, and is under $10
#
# FLDM has uncle"s pattern with high volume on 20200505, and is under $10
#
# GERN has uncle"s pattern with high volume on 20200518, and is under $10
#
# GERN has uncle"s pattern with high volume on 20200515, and is under $10
#
# GERN has uncle"s pattern with high volume on 20200511, and is under $10
#
# GLMD has uncle"s pattern with high volume on 20200519, and is under $10
#
# GNCA has uncle"s pattern with high volume on 20200507, and is under $10
#
# GNLN has uncle"s pattern with high volume on 20200526, and is under $10
#
# GNUS has uncle"s pattern with high volume on 20200513, and is under $10
#
# GNUS has uncle"s pattern with high volume on 20200511, and is under $10
#
# GNUS has uncle"s pattern with high volume on 20200507, and is under $10
#
# GPRO has uncle"s pattern with high volume on 20200527, and is under $10
#
# GRNQ has uncle"s pattern with high volume on 20200527, and is under $10
#
# GRNQ has uncle"s pattern with high volume on 20200526, and is under $10
#
# GTBI has uncle"s pattern with high volume on 20200515, and is under $10
#
# GUY. has uncle"s pattern with high volume on 20200519, and is under $10
#
# GUY. has uncle"s pattern with high volume on 20200506, and is under $10
#
# GUYF has uncle"s pattern with high volume on 20200518, and is under $10
#
# IDYA has uncle"s pattern with high volume on 20200528, and is under $10
#
# IGC has uncle"s pattern with high volume on 20200522, and is under $10
#
# IGC has uncle"s pattern with high volume on 20200521, and is under $10
#
# IMBI has uncle"s pattern with high volume on 20200527, and is under $10
#
# IZEA has uncle"s pattern with high volume on 20200506, and is under $10
#
# KGFH.csv 20200505
# Traceback (most recent call last):
#   File "<ipython-input-14-b2e26f3175a2>", line 11, in <module>
#     ticker_df = pd.read_csv(os.path.join(directory, f))
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 702, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 435, in _read
#     data = parser.read(nrows)
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 1139, in read
#     ret = self._engine.read(nrows)
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 1995, in read
#     data = self._reader.read(nrows)
#   File "pandas/_libs/parsers.pyx", line 899, in pandas._libs.parsers.TextReader.read
#   File "pandas/_libs/parsers.pyx", line 914, in pandas._libs.parsers.TextReader._read_low_memory
#   File "pandas/_libs/parsers.pyx", line 968, in pandas._libs.parsers.TextReader._read_rows
#   File "pandas/_libs/parsers.pyx", line 955, in pandas._libs.parsers.TextReader._tokenize_rows
#   File "pandas/_libs/parsers.pyx", line 2172, in pandas._libs.parsers.raise_parser_error
# pandas.errors.ParserError: Error tokenizing data. C error: Expected 17 fields in line 33, saw 22
#
#
# <traceback object at 0x0000028E5C84F888>
# KIRK has uncle"s pattern with high volume on 20200527, and is under $10
#
# KOPN has uncle"s pattern with high volume on 20200511, and is under $10
#
# KOR. has uncle"s pattern with high volume on 20200514, and is under $10
#
# LEDS has uncle"s pattern with high volume on 20200521, and is under $10
#
# LEDS has uncle"s pattern with high volume on 20200520, and is under $10
#
# LL has uncle"s pattern with high volume on 20200527, and is under $10
#
# LMFA has uncle"s pattern with high volume on 20200520, and is under $10
#
# LPCN has uncle"s pattern with high volume on 20200518, and is under $10
#
# LPCN has uncle"s pattern with high volume on 20200507, and is under $10
#
# LTBR has uncle"s pattern with high volume on 20200505, and is under $10
#
# LTRX has uncle"s pattern with high volume on 20200521, and is under $10
#
# MARK has uncle"s pattern with high volume on 20200511, and is under $10
#
# MARK has uncle"s pattern with high volume on 20200507, and is under $10
#
# MARK has uncle"s pattern with high volume on 20200506, and is under $10
#
# MBIO has uncle"s pattern with high volume on 20200526, and is under $10
#
# MGI has uncle"s pattern with high volume on 20200527, and is under $10
#
# MGI has uncle"s pattern with high volume on 20200526, and is under $10
#
# MITO has uncle"s pattern with high volume on 20200518, and is under $10
#
# NCNA has uncle"s pattern with high volume on 20200520, and is under $10
#
# NEPT has uncle"s pattern with high volume on 20200522, and is under $10
#
# NHTC has uncle"s pattern with high volume on 20200529, and is under $10
#
# NNDM has uncle"s pattern with high volume on 20200521, and is under $10
#
# NNDM has uncle"s pattern with high volume on 20200519, and is under $10
#
# OBSV has uncle"s pattern with high volume on 20200511, and is under $10
#
# ONCS has uncle"s pattern with high volume on 20200519, and is under $10
#
# PEIX has uncle"s pattern with high volume on 20200529, and is under $10
#
# PEIX has uncle"s pattern with high volume on 20200521, and is under $10
#
# PHUN has uncle"s pattern with high volume on 20200520, and is under $10
#
# PKCO.csv 20200505
# Traceback (most recent call last):
#   File "<ipython-input-14-b2e26f3175a2>", line 11, in <module>
#     ticker_df = pd.read_csv(os.path.join(directory, f))
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 702, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 435, in _read
#     data = parser.read(nrows)
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 1139, in read
#     ret = self._engine.read(nrows)
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 1995, in read
#     data = self._reader.read(nrows)
#   File "pandas/_libs/parsers.pyx", line 899, in pandas._libs.parsers.TextReader.read
#   File "pandas/_libs/parsers.pyx", line 914, in pandas._libs.parsers.TextReader._read_low_memory
#   File "pandas/_libs/parsers.pyx", line 968, in pandas._libs.parsers.TextReader._read_rows
#   File "pandas/_libs/parsers.pyx", line 955, in pandas._libs.parsers.TextReader._tokenize_rows
#   File "pandas/_libs/parsers.pyx", line 2172, in pandas._libs.parsers.raise_parser_error
# pandas.errors.ParserError: Error tokenizing data. C error: Expected 17 fields in line 64, saw 20
#
#
# <traceback object at 0x0000028E5C863BC8>
# REFR has uncle"s pattern with high volume on 20200511, and is under $10
#
# RENN has uncle"s pattern with high volume on 20200526, and is under $10
#
# RENN has uncle"s pattern with high volume on 20200522, and is under $10
#
# RENN has uncle"s pattern with high volume on 20200521, and is under $10
#
# RENN has uncle"s pattern with high volume on 20200520, and is under $10
#
# RIOT has uncle"s pattern with high volume on 20200508, and is under $10
#
# RIOT has uncle"s pattern with high volume on 20200507, and is under $10
#
# RNWK has uncle"s pattern with high volume on 20200528, and is under $10
#
# RNWK has uncle"s pattern with high volume on 20200527, and is under $10
#
# RNX. has uncle"s pattern with high volume on 20200508, and is under $10
#
# RWLK has uncle"s pattern with high volume on 20200519, and is under $10
#
# SGMO has uncle"s pattern with high volume on 20200512, and is under $10
#
# SGMO has uncle"s pattern with high volume on 20200505, and is under $10
#
# SLS has uncle"s pattern with high volume on 20200521, and is under $10
#
# SNCA has uncle"s pattern with high volume on 20200521, and is under $10
#
# STAG.csv 20200505
# Traceback (most recent call last):
#   File "<ipython-input-14-b2e26f3175a2>", line 11, in <module>
#     ticker_df = pd.read_csv(os.path.join(directory, f))
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 702, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 435, in _read
#     data = parser.read(nrows)
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 1139, in read
#     ret = self._engine.read(nrows)
#   File "C:\Users\Richard\Anaconda3\lib\site-packages\pandas\io\parsers.py", line 1995, in read
#     data = self._reader.read(nrows)
#   File "pandas/_libs/parsers.pyx", line 899, in pandas._libs.parsers.TextReader.read
#   File "pandas/_libs/parsers.pyx", line 914, in pandas._libs.parsers.TextReader._read_low_memory
#   File "pandas/_libs/parsers.pyx", line 968, in pandas._libs.parsers.TextReader._read_rows
#   File "pandas/_libs/parsers.pyx", line 955, in pandas._libs.parsers.TextReader._tokenize_rows
#   File "pandas/_libs/parsers.pyx", line 2172, in pandas._libs.parsers.raise_parser_error
# pandas.errors.ParserError: Error tokenizing data. C error: Expected 17 fields in line 32, saw 27
#
#
# <traceback object at 0x0000028E5C862F88>
# TCW. has uncle"s pattern with high volume on 20200528, and is under $10
#
# TENX has uncle"s pattern with high volume on 20200528, and is under $10
#
# TIGR has uncle"s pattern with high volume on 20200526, and is under $10
#
# TIGR has uncle"s pattern with high volume on 20200520, and is under $10
#
# TORC has uncle"s pattern with high volume on 20200508, and is under $10
#
# TORC has uncle"s pattern with high volume on 20200505, and is under $10
#
# TRVN has uncle"s pattern with high volume on 20200511, and is under $10
#
# TRX has uncle"s pattern with high volume on 20200512, and is under $10
#
# TRX has uncle"s pattern with high volume on 20200511, and is under $10
#
# TTPH has uncle"s pattern with high volume on 20200522, and is under $10
#
# UBX has uncle"s pattern with high volume on 20200515, and is under $10
#
# UPWK has uncle"s pattern with high volume on 20200507, and is under $10
#
# VFF has uncle"s pattern with high volume on 20200526, and is under $10
#
# VFF has uncle"s pattern with high volume on 20200522, and is under $10
#
# VUZI has uncle"s pattern with high volume on 20200522, and is under $10
#
# VUZI has uncle"s pattern with high volume on 20200508, and is under $10
#
# VUZI has uncle"s pattern with high volume on 20200507, and is under $10
#
# WILD has uncle"s pattern with high volume on 20200520, and is under $10
#
# XCUR has uncle"s pattern with high volume on 20200511, and is under $10
#
# YCBD has uncle"s pattern with high volume on 20200518, and is under $10
#
# ZSAN has uncle"s pattern with high volume on 20200527, and is under $10
#
# ZYNE has uncle"s pattern with high volume on 20200522, and is under $10

# %%
print (to_send)
print (to_save)
# Out:
# ABEO has uncle"s pattern with high volume on 20200511, and is under $10
# AFMD has uncle"s pattern with high volume on 20200519, and is under $10
# ANY has uncle"s pattern with high volume on 20200505, and is under $10
# ASM has uncle"s pattern with high volume on 20200521, and is under $10
# ASM has uncle"s pattern with high volume on 20200519, and is under $10
# AUG has uncle"s pattern with high volume on 20200522, and is under $10
# AXIM has uncle"s pattern with high volume on 20200526, and is under $10
# AXU has uncle"s pattern with high volume on 20200515, and is under $10
# CANF has uncle"s pattern with high volume on 20200522, and is under $10
# CANF has uncle"s pattern with high volume on 20200521, and is under $10
# CASI has uncle"s pattern with high volume on 20200521, and is under $10
# CBAY has uncle"s pattern with high volume on 20200511, and is under $10
# CCHW has uncle"s pattern with high volume on 20200528, and is under $10
# CFMS has uncle"s pattern with high volume on 20200511, and is under $10
# CIDM has uncle"s pattern with high volume on 20200520, and is under $10
# CLSN has uncle"s pattern with high volume on 20200522, and is under $10
# CLSN has uncle"s pattern with high volume on 20200521, and is under $10
# CLSN has uncle"s pattern with high volume on 20200520, and is under $10
# CMT has uncle"s pattern with high volume on 20200511, and is under $10
# CNET has uncle"s pattern with high volume on 20200527, and is under $10
# CPST has uncle"s pattern with high volume on 20200511, and is under $10
# CURL has uncle"s pattern with high volume on 20200518, and is under $10
# CVSI has uncle"s pattern with high volume on 20200526, and is under $10
# CVSI has uncle"s pattern with high volume on 20200522, and is under $10
# DCAR has uncle"s pattern with high volume on 20200521, and is under $10
# DCAR has uncle"s pattern with high volume on 20200515, and is under $10
# DFIN has uncle"s pattern with high volume on 20200529, and is under $10
# EDUC has uncle"s pattern with high volume on 20200528, and is under $10
# ENOB has uncle"s pattern with high volume on 20200513, and is under $10
# FLDM has uncle"s pattern with high volume on 20200505, and is under $10
# GERN has uncle"s pattern with high volume on 20200518, and is under $10
# GERN has uncle"s pattern with high volume on 20200515, and is under $10
# GERN has uncle"s pattern with high volume on 20200511, and is under $10
# GLMD has uncle"s pattern with high volume on 20200519, and is under $10
# GNCA has uncle"s pattern with high volume on 20200507, and is under $10
# GNLN has uncle"s pattern with high volume on 20200526, and is under $10
# GNUS has uncle"s pattern with high volume on 20200513, and is under $10
# GNUS has uncle"s pattern with high volume on 20200511, and is under $10
# GNUS has uncle"s pattern with high volume on 20200507, and is under $10
# GPRO has uncle"s pattern with high volume on 20200527, and is under $10
# GRNQ has uncle"s pattern with high volume on 20200527, and is under $10
# GRNQ has uncle"s pattern with high volume on 20200526, and is under $10
# GTBI has uncle"s pattern with high volume on 20200515, and is under $10
# GUY. has uncle"s pattern with high volume on 20200519, and is under $10
# GUY. has uncle"s pattern with high volume on 20200506, and is under $10
# GUYF has uncle"s pattern with high volume on 20200518, and is under $10
# IDYA has uncle"s pattern with high volume on 20200528, and is under $10
# IGC has uncle"s pattern with high volume on 20200522, and is under $10
# IGC has uncle"s pattern with high volume on 20200521, and is under $10
# IMBI has uncle"s pattern with high volume on 20200527, and is under $10
# IZEA has uncle"s pattern with high volume on 20200506, and is under $10
# KIRK has uncle"s pattern with high volume on 20200527, and is under $10
# KOPN has uncle"s pattern with high volume on 20200511, and is under $10
# KOR. has uncle"s pattern with high volume on 20200514, and is under $10
# LEDS has uncle"s pattern with high volume on 20200521, and is under $10
# LEDS has uncle"s pattern with high volume on 20200520, and is under $10
# LL has uncle"s pattern with high volume on 20200527, and is under $10
# LMFA has uncle"s pattern with high volume on 20200520, and is under $10
# LPCN has uncle"s pattern with high volume on 20200518, and is under $10
# LPCN has uncle"s pattern with high volume on 20200507, and is under $10
# LTBR has uncle"s pattern with high volume on 20200505, and is under $10
# LTRX has uncle"s pattern with high volume on 20200521, and is under $10
# MARK has uncle"s pattern with high volume on 20200511, and is under $10
# MARK has uncle"s pattern with high volume on 20200507, and is under $10
# MARK has uncle"s pattern with high volume on 20200506, and is under $10
# MBIO has uncle"s pattern with high volume on 20200526, and is under $10
# MGI has uncle"s pattern with high volume on 20200527, and is under $10
# MGI has uncle"s pattern with high volume on 20200526, and is under $10
# MITO has uncle"s pattern with high volume on 20200518, and is under $10
# NCNA has uncle"s pattern with high volume on 20200520, and is under $10
# NEPT has uncle"s pattern with high volume on 20200522, and is under $10
# NHTC has uncle"s pattern with high volume on 20200529, and is under $10
# NNDM has uncle"s pattern with high volume on 20200521, and is under $10
# NNDM has uncle"s pattern with high volume on 20200519, and is under $10
# OBSV has uncle"s pattern with high volume on 20200511, and is under $10
# ONCS has uncle"s pattern with high volume on 20200519, and is under $10
# PEIX has uncle"s pattern with high volume on 20200529, and is under $10
# PEIX has uncle"s pattern with high volume on 20200521, and is under $10
# PHUN has uncle"s pattern with high volume on 20200520, and is under $10
# REFR has uncle"s pattern with high volume on 20200511, and is under $10
# RENN has uncle"s pattern with high volume on 20200526, and is under $10
# RENN has uncle"s pattern with high volume on 20200522, and is under $10
# RENN has uncle"s pattern with high volume on 20200521, and is under $10
# RENN has uncle"s pattern with high volume on 20200520, and is under $10
# RIOT has uncle"s pattern with high volume on 20200508, and is under $10
# RIOT has uncle"s pattern with high volume on 20200507, and is under $10
# RNWK has uncle"s pattern with high volume on 20200528, and is under $10
# RNWK has uncle"s pattern with high volume on 20200527, and is under $10
# RNX. has uncle"s pattern with high volume on 20200508, and is under $10
# RWLK has uncle"s pattern with high volume on 20200519, and is under $10
# SGMO has uncle"s pattern with high volume on 20200512, and is under $10
# SGMO has uncle"s pattern with high volume on 20200505, and is under $10
# SLS has uncle"s pattern with high volume on 20200521, and is under $10
# SNCA has uncle"s pattern with high volume on 20200521, and is under $10
# TCW. has uncle"s pattern with high volume on 20200528, and is under $10
# TENX has uncle"s pattern with high volume on 20200528, and is under $10
# TIGR has uncle"s pattern with high volume on 20200526, and is under $10
# TIGR has uncle"s pattern with high volume on 20200520, and is under $10
# TORC has uncle"s pattern with high volume on 20200508, and is under $10
# TORC has uncle"s pattern with high volume on 20200505, and is under $10
# TRVN has uncle"s pattern with high volume on 20200511, and is under $10
# TRX has uncle"s pattern with high volume on 20200512, and is under $10
# TRX has uncle"s pattern with high volume on 20200511, and is under $10
# TTPH has uncle"s pattern with high volume on 20200522, and is under $10
# UBX has uncle"s pattern with high volume on 20200515, and is under $10
# UPWK has uncle"s pattern with high volume on 20200507, and is under $10
# VFF has uncle"s pattern with high volume on 20200526, and is under $10
# VFF has uncle"s pattern with high volume on 20200522, and is under $10
# VUZI has uncle"s pattern with high volume on 20200522, and is under $10
# VUZI has uncle"s pattern with high volume on 20200508, and is under $10
# VUZI has uncle"s pattern with high volume on 20200507, and is under $10
# WILD has uncle"s pattern with high volume on 20200520, and is under $10
# XCUR has uncle"s pattern with high volume on 20200511, and is under $10
# YCBD has uncle"s pattern with high volume on 20200518, and is under $10
# ZSAN has uncle"s pattern with high volume on 20200527, and is under $10
# ZYNE has uncle"s pattern with high volume on 20200522, and is under $10
#
# ^DJI
# ABEO
# AFMD
# ANY
# ASM
# ASM
# AUG
# AXIM
# AXU
# CANF
# CANF
# CASI
# CBAY
# CCHW
# CFMS
# CIDM
# CLSN
# CLSN
# CLSN
# CMT
# CNET
# CPST
# CURL
# CVSI
# CVSI
# DCAR
# DCAR
# DFIN
# EDUC
# ENOB
# FLDM
# GERN
# GERN
# GERN
# GLMD
# GNCA
# GNLN
# GNUS
# GNUS
# GNUS
# GPRO
# GRNQ
# GRNQ
# GTBI
# GUY.
# GUY.
# GUYF
# IDYA
# IGC
# IGC
# IMBI
# IZEA
# KIRK
# KOPN
# KOR.
# LEDS
# LEDS
# LL
# LMFA
# LPCN
# LPCN
# LTBR
# LTRX
# MARK
# MARK
# MARK
# MBIO
# MGI
# MGI
# MITO
# NCNA
# NEPT
# NHTC
# NNDM
# NNDM
# OBSV
# ONCS
# PEIX
# PEIX
# PHUN
# REFR
# RENN
# RENN
# RENN
# RENN
# RIOT
# RIOT
# RNWK
# RNWK
# RNX.
# RWLK
# SGMO
# SGMO
# SLS
# SNCA
# TCW.
# TENX
# TIGR
# TIGR
# TORC
# TORC
# TRVN
# TRX
# TRX
# TTPH
# UBX
# UPWK
# VFF
# VFF
# VUZI
# VUZI
# VUZI
# WILD
# XCUR
# YCBD
# ZSAN
# ZYNE

# %%
#replace intraday symbols file
with open('C:\\Users\\Richard\\Desktop\\Python\\Investing2.0\\Intraday_Analysis\\symbolsIntraD.txt', 'w+') as symbol_file:
    symbol_file.write(to_save)

# %%
#Ascending Triangle pattern
import traceback
#clear memory
gc.collect()
to_send = ''
directory = './data_nasdaq/'
# get list with filenames in folder and throw away all non ncsv
files = [f for f in os.listdir(directory) if f.endswith('.csv')]
for f in files:
    try:
        stock_df = pd.read_csv(os.path.join(directory, f))

        for i in range(int((len(stock_df)*0.5))): #looping through last % of data
            
            window = 29 #number of days back from today to look at
            
            i += 1 #start range from 1 instead of 0
            
            openTday =  float(stock_df['open'].iloc[-i])
            closeTday =  float(stock_df['close'].iloc[-i])
            volumeTdayP = (float(stock_df['volume'].iloc[-i])+0.001)/(float(stock_df['vol20'].iloc[-i])+0.001)

            sma5 = float(stock_df['sma5'].iloc[-(i+1)])
            sma8 = float(stock_df['sma8'].iloc[-(i+1)])
            sma13 = float(stock_df['sma13'].iloc[-(i+1)])
            
            #normalize with moving average
            stock_df['high'] = stock_df['high']/stock_df['sma5']
            stock_df['low'] = stock_df['low']/stock_df['sma5']
            stock_df['volume'] = stock_df['volume']/stock_df['vol20']
            
            #range of variables
            df_normalized_high = stock_df['high'][-(i+window):-(i+1)]
            df_normalized_low = stock_df['low'][-(i+window):-(i+1)]
            df_normalized_vol = stock_df['volume'].iloc[-(i+window):-(i+1)]


            #top x points of high
            df_normalized_high=df_normalized_high.nlargest(3,keep='first')
            high_index_diff1 = abs(df_normalized_high.sort_values().index[0] -df_normalized_high.sort_values().index[1])
            high_index_diff2 = abs(df_normalized_high.sort_values().index[1] -df_normalized_high.sort_values().index[2])
            #lowest x points of low
            df_normalized_low=df_normalized_low.nsmallest(3,keep='first')
            low_index_diff1 = abs(df_normalized_low.sort_values().index[0] -df_normalized_low.sort_values().index[1])
            low_index_diff2 = abs(df_normalized_low.sort_values().index[1] -df_normalized_low.sort_values().index[2])
            #compute slopes
            slope_high_Xd = np.polyfit(df_normalized_high.index, df_normalized_high, 1)[0]
            slope_low_Xd = np.polyfit(df_normalized_low.index, df_normalized_low, 1)[0]
            slope_volume_Xd = np.polyfit(df_normalized_vol.index, df_normalized_vol, 1)[0]
            
            #print(f,slope_high_Xd,slope_low_Xd,slope_volume_Xd)
                      
            #core logic
            if closeTday > openTday\
                and high_index_diff1 > 3\
                and high_index_diff2 > 3\
                and low_index_diff1 > 3\
                and low_index_diff2 > 3\
                and slope_high_Xd > -0.01\
                and slope_low_Xd > (slope_high_Xd+0.0001)\
                and sma5<closeTday\
                and sma8<closeTday\
                and sma13<closeTday\
                and closeTday <= 50 and closeTday >= 0.5\
                and volumeTdayP >3:

                to_send += '{} has Ascending Triangle pattern on {}, and is under $20 \n'.format(f[:-4],(stock_df['Unnamed: 0'].iloc[-i]))
                print ('{} has Ascending Triangle pattern on {}, and is under $20 \n'.format(f[:-4],(stock_df['Unnamed: 0'].iloc[-i])))
        
    except IndexError:
        pass
    except Exception:
        print(f,stock_df['Unnamed: 0'].iloc[-i])
        print(traceback.format_exc())
        # or
        print(sys.exc_info()[2])

# %%
#email output
with open('C:\\Users\\Richard\\Desktop\\Python\\hotmail.txt', 'rb') as f:
    email_list = str(f.read()).split(',')
    emailAddress = email_list[0][2:]
    password = email_list[1][:-1]

    msg = MIMEText(to_send)
    recipients = [emailAddress, 'michelleusdenski@gmail.com','Guowei88888@msn.com']#'jacob.si@outlook.com','Greggh_101@hotmail.com','Guowei88888@msn.com']
    msg['Subject'] = '%s stock analysis: Daily Candle potentials - %s' % (str(datetime.datetime.today().strftime('%Y-%m-%d')), str(len(to_send.split('\n'))-1))
    msg['From'] = emailAddress
    msg['To'] = ', '.join(recipients)
    try:
        s = smtplib.SMTP('smtp-mail.outlook.com', 25)
        s.ehlo()  # Hostname to send for this command defaults to the fully qualified domain name of the local host.
        s.starttls()  # Puts connection to SMTP server in TLS mode
        s.ehlo()
        s.login(emailAddress, password)
        s.sendmail(emailAddress, recipients, msg.as_string())
        s.quit()
        print ('email sent to: %s' % emailAddress)
    except:
        raise
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-9d035b9ba397> in <module>
#      11     msg['To'] = ', '.join(recipients)
#      12     try:
# ---> 13         s = smtplib.SMTP('smtp-mail.outlook.com', 25)
#      14         s.ehlo()  # Hostname to send for this command defaults to the fully qualified domain name of the local host.
#      15         s.starttls()  # Puts connection to SMTP server in TLS mode
#
# ~\Anaconda3\lib\smtplib.py in __init__(self, host, port, local_hostname, timeout, source_address)
#     249
#     250         if host:
# --> 251             (code, msg) = self.connect(host, port)
#     252             if code != 220:
#     253                 self.close()
#
# ~\Anaconda3\lib\smtplib.py in connect(self, host, port, source_address)
#     334         if self.debuglevel > 0:
#     335             self._print_debug('connect:', (host, port))
# --> 336         self.sock = self._get_socket(host, port, self.timeout)
#     337         self.file = None
#     338         (code, msg) = self.getreply()
#
# ~\Anaconda3\lib\smtplib.py in _get_socket(self, host, port, timeout)
#     305             self._print_debug('connect: to', (host, port), self.source_address)
#     306         return socket.create_connection((host, port), timeout,
# --> 307                                         self.source_address)
#     308
#     309     def connect(self, host='localhost', port=0, source_address=None):
#
# ~\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     725
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#     729         raise error("getaddrinfo returns an empty list")
#
# ~\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     714             if source_address:
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#     718             err = None
#
# OSError: [WinError 10051] A socket operation was attempted to an unreachable network
