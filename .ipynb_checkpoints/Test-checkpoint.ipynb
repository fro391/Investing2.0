# %%
import datetime
import time
import requests

import json
import os
import pandas as pd
import numpy as np

#threading
import threading
import timeit

from email.mime.text import MIMEText
import smtplib

#declare global lock object
global lock
lock = threading.Lock()

# %%
def symbol_downloader(symbol, directory, days=60, days_ago=0):
    dt = datetime.datetime.now()
    UnixTime = int(time.mktime(dt.timetuple()))
    #web variables
    url = 'https://query1.finance.yahoo.com/v8/finance/chart/'+symbol+'?period1='+str(UnixTime-86400*(days+days_ago))+'&period2='+str(UnixTime-86400*days_ago)+'&interval=1d&indicators=quote%7Csma~60&includePrePost=true&events=div%7Csplit%7Cearn&lang=en-CA&region=CA&corsDomain=ca.finance.yahoo.com'
    #proxies
    http_proxy  = ''
    https_proxy = ''
    ftp_proxy   = ''
    proxyDict = { 
                  "http"  : http_proxy, 
                  "https" : https_proxy, 
                  "ftp"   : ftp_proxy
                }

    hdr = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.101 Safari/537.36',
       'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
       'Connection': 'keep-alive'}
    
    try:
        resp = requests.get(url, headers=hdr)
        if resp.status_code != 200:
            # This means something went wrong.
            print(resp.status_code)
        data = json.loads(resp.text)
        #json unpack
        timestamp = data['chart']['result'][0]['timestamp']
        timestamp = [datetime.datetime.fromtimestamp(x).strftime('%Y%m%d') for x in timestamp]
        quote = data['chart']['result'][0]['indicators']['quote'][0]
        sma50 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
        stock_df = pd.DataFrame(quote)
        #index is symbol and timestamp
        stock_df.index = [str(x) for x in timestamp]

        #moving averages
        stock_df['sma'] = sma50
        stock_df['vol20'] = stock_df['volume'].rolling(window=20).mean()
        #predict on yesterday's averages
        stock_df['sma'] = stock_df['sma'].shift(1)
        stock_df['vol20'] = stock_df['vol20'].shift(1)
        stock_df = stock_df.dropna()

        #derived columns
#         stock_df['close'] = stock_df['close']/stock_df['sma']
#         stock_df['high'] = stock_df['high']/stock_df['sma']
#         stock_df['low'] = stock_df['low']/stock_df['sma']
#         stock_df['open'] = stock_df['open']/stock_df['sma']
        stock_df['volume'] = stock_df['volume']/stock_df['vol20']

        #stock_df.drop(['close', 'high', 'low', 'open','volume','sma','vol20'], axis=1, inplace=True)
        stock_df = stock_df.dropna()
        stock_df = stock_df[~(stock_df == np.inf).any(axis=1)]
        if len(stock_df) != 0:
            stock_df.to_csv('{}{}.csv'.format(directory,symbol[:4]))
        
    except requests.exceptions.RequestException as e:  # This is the correct syntax
        raise SystemExit(e)

# %%
if __name__ == '__main__':

    #start timer
    start = timeit.default_timer()

    symbolslist = open('symbols.txt').read().split('\n')

    directory = './data_nasdaq/'

    threadlist = []

    for u in symbolslist:

        t = threading.Thread(target = symbol_downloader,args=(u,directory))
        t.start()
        threadlist.append(t)
        #sets top limit of active threads to 50
        while threading.activeCount()>50:
            a=0
        #print threading.activeCount()

    for b in threadlist:
        b.join()
    print ("# of threads: ", len(threadlist))
# Out:
# 404
# Exception in thread Thread-18:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-11:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-19:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404404
#
# 404
# Exception in thread Thread-32:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-33:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-37:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-34:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-26:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-42:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-43:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-58:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-55:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-66:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-65:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-52:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-69:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-73:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-77:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-76:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-60:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 30, in symbol_downloader
#     sma50 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-98:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-71:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-59:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-94:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-118:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-113:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-125:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# Exception in thread Thread-127:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
#
# Exception in thread Thread-124:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-129:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-96:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-137:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-143:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-158:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-159:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-164:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-176:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-179:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-185:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-191:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-190:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-194:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-207:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-211:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-221:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-231:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 30, in symbol_downloader
#     sma50 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
# 404
# Exception in thread Thread-239:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-246:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-51:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-247:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 30, in symbol_downloader
#     sma50 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
# 404
# Exception in thread Thread-258:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-273:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-278:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-281:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-282:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 30, in symbol_downloader
#     sma50 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
# 404
# Exception in thread Thread-30:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-291:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-295:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-298:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-314:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 30, in symbol_downloader
#     sma50 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-315:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-323:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-329:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-331:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 30, in symbol_downloader
#     sma50 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-343:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-347:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-348:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-350:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# 404
# Exception in thread Thread-352:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# Exception in thread Thread-359:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
#
# Exception in thread Thread-365:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-378:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# 404
# Exception in thread Thread-369:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-379:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-384:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-387:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-368:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-396:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-402:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-407:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-410:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-422:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-421:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-424:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-444:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-430:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-429:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-441:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-458:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-464:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-463:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-466:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-473:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-487:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-485:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-493:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-496:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-510:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 30, in symbol_downloader
#     sma50 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-516:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-526:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-527:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-533:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-540:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-561:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-575:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-580:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 30, in symbol_downloader
#     sma50 = data['chart']['result'][0]['indicators']['sma'][0]['sma']
# KeyError: 'sma'
#
# Exception in thread Thread-583:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-589:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
# ...
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-9263:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-9296:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-9326:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-9356:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-9388:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-9406:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-9433:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-9463:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-9473:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-9533:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-9534:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-9544:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-9629:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-9661:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-9670:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-9713:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-9744:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-9780:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-9787:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-9797:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
#
# Exception in thread Thread-9925:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-9928:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-9946:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-9978:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-10016:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-10021:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-10034:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-10056:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
#
# Exception in thread Thread-10092:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# KeyError: 'timestamp'
# 404
# Exception in thread Thread-10086:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-10133:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-10140:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-10179:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable
# 404
# Exception in thread Thread-10244:
# Traceback (most recent call last):
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Richard\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-4d2a03930e50>", line 27, in symbol_downloader
#     timestamp = data['chart']['result'][0]['timestamp']
# TypeError: 'NoneType' object is not subscriptable

# %%
#Analyze
to_send = ''
directory = './data_nasdaq/'
# get list with filenames in folder and throw away all non ncsv
files = [f for f in os.listdir(directory) if f.endswith('.csv')]
for f in files:
    try:
        stock_df = pd.read_csv(os.path.join(directory, f))

        for i in range(int((len(stock_df)*0.5))): #engulfing candel pattern looping through all available data 
            i += 1 #start range from 1 instead of 0
            if float(stock_df['close'].iloc[-(i+1)]) < float(stock_df['open'].iloc[-(i+1)]) \
                and float(stock_df['close'].iloc[-i]) > float(stock_df['open'].iloc[-(i+1)]) \
                and float(stock_df['open'].iloc[-i]) < float(stock_df['close'].iloc[-(i+1)]) \
                and (float(stock_df['close'].iloc[-i])/float(stock_df['sma'].iloc[-i])) >= 1 \
                and float(stock_df['close'].iloc[-i]) <= 20 and float(stock_df['close'].iloc[-i]) >= 2 \
                and float(stock_df['volume'].iloc[-i]) >= 3:

                to_send += '{} has engulfing candle with high volume on {}, and is under $20 \n'.format(f[:-4],(stock_df['Unnamed: 0'].iloc[-i]))
                print ('{} has engulfing candle with high volume on {}, and is under $20 \n'.format(f[:-4],(stock_df['Unnamed: 0'].iloc[-i])))
                
    except requests.exceptions.RequestException as e:  # This is the correct syntax
        print (f)
        raise SystemExit(e)
# Out:
# AXTI has engulfing candel with high volume on 20200430, and is under $20
#
# BASI has engulfing candel with high volume on 20200427, and is under $20
#
# BKEP has engulfing candel with high volume on 20200508, and is under $20
#
# FLDM has engulfing candel with high volume on 20200501, and is under $20
#
# JSTT has engulfing candel with high volume on 20200225, and is under $20
#
# LEDS has engulfing candel with high volume on 20200506, and is under $20
#
# LUNA has engulfing candel with high volume on 20200508, and is under $20
#
# OSTK has engulfing candel with high volume on 20200424, and is under $20
#
# QRTE has engulfing candel with high volume on 20200429, and is under $20
#
# RCON has engulfing candel with high volume on 20200424, and is under $20
#
# REFR has engulfing candel with high volume on 20200507, and is under $20
#
# SQNS has engulfing candel with high volume on 20200423, and is under $20
#
# TBIO has engulfing candel with high volume on 20200424, and is under $20

# %%
#email output
with open('C:\\Users\\Richard\\Desktop\\Python\\hotmail.txt', 'rb') as f:
    email_list = str(f.read()).split(',')
    emailAddress = email_list[0][2:]
    password = email_list[1][:-1]

    msg = MIMEText(to_send)
    recipients = [emailAddress, 'michelleusdenski@gmail.com','Guowei88888@msn.com']#'jacob.si@outlook.com','Greggh_101@hotmail.com']
    msg['Subject'] = '%s stock analysis: potentials - %s' % (str(datetime.datetime.today().strftime('%Y-%m-%d')), str(len(to_send.split('\n'))-1))
    msg['From'] = emailAddress
    msg['To'] = ', '.join(recipients)
    try:
        s = smtplib.SMTP('smtp-mail.outlook.com', 25)
        s.ehlo()  # Hostname to send for this command defaults to the fully qualified domain name of the local host.
        s.starttls()  # Puts connection to SMTP server in TLS mode
        s.ehlo()
        s.login(emailAddress, password)
        s.sendmail(emailAddress, recipients, msg.as_string())
        s.quit()
        print ('email sent to: %s' % emailAddress)
    except:
        raise
        
#timer
stop = timeit.default_timer()
print ("seconds of operation: " , stop - start)
# Out:
# email sent to: richardguo0122@hotmail.com
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9e247e94aa49> in <module>
#      24 #timer
#      25 stop = timeit.default_timer()
# ---> 26 print ("seconds of operation: " , stop - start)
#
# NameError: name 'start' is not defined
